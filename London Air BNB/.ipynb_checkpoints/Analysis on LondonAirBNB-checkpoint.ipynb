# %% [markdown]
# dataset: https://www.kaggle.com/datasets/jinxzed/londonairbnb?select=Uphaar_listing.csv

# %%
import pandas as pd, numpy as np,matplotlib.pyplot as plt, seaborn as sns
from sklearn.preprocessing import LabelEncoder
import statsmodels.api as sm
pd.options.display.max_columns=50

# %%
df=pd.read_csv(r"A:\datasets\Uphaar_listing.csv\Uphaar_listing.csv")
df.head()
# Out:
#    Unnamed: 0  price_x experiences_offered host_is_superhost  \
# 0           0       88              family                 f
# 1           1       65            business                 f
# 2           2      100            romantic                 f
# 3           3      300                none                 f
# 4           4      150            business                 f
#
#    host_listings_count host_has_profile_pic host_identity_verified  \
# 0                  3.0                    t                      t
# 1                  4.0                    t                      t
# 2                  1.0                    t                      t
# 3                 18.0                    t                      t
# 4                  3.0                    t                      f
#
#   is_location_exact      property_type      room_type_y  accommodates  \
# 0                 t          Apartment  Entire home/apt             4
# 1                 t          Apartment     Private room             2
# 2                 t          Apartment  Entire home/apt             2
# 3                 f          Apartment  Entire home/apt             6
# 4                 t  Bed and breakfast     Private room             2
#
#    bathrooms  bedrooms  beds  bed_type  guests_included  extra_people  \
# 0        1.0       1.0   3.0  Real Bed                2          20.0
# 1        1.0       1.0   0.0  Real Bed                1          15.0
# 2        1.0       1.0   1.0  Real Bed                2           0.0
# 3        2.0       3.0   3.0  Real Bed                3          10.0
# 4        1.0       1.0   1.0  Real Bed                1           0.0
#
#    minimum_nights_y  maximum_nights  availability_30  availability_60  \
# 0                 2             180               12               42
# 1                 1              29               12               42
# 2                10              50                0                0
# 3                 3             365                9               39
# 4                 3              21               11               41
#
#    availability_90  availability_365_y  number_of_reviews_y  \
# 0               72                 347                  192
# 1               72                 347                   21
# 2               13                 288                   89
# 3               69                 326                   42
# 4               71                 346                    0
#
#    number_of_reviews_ltm requires_license instant_bookable  \
# 0                      9                f                t
# 1                      5                f                f
# 2                      4                f                t
# 3                      2                f                t
# 4                      0                f                f
#
#   is_business_travel_ready          cancellation_policy  \
# 0                        f  strict_14_with_grace_period
# 1                        f                     moderate
# 2                        f  strict_14_with_grace_period
# 3                        f  strict_14_with_grace_period
# 4                        f  strict_14_with_grace_period
#
#   require_guest_profile_picture require_guest_phone_verification  \
# 0                             f                                t
# 1                             f                                f
# 2                             t                                t
# 3                             f                                f
# 4                             f                                f
#
#    calculated_host_listings_count_y  \
# 0                                 2
# 1                                 3
# 2                                 1
# 3                                15
# 4                                 2
#
#    calculated_host_listings_count_entire_homes  \
# 0                                            2
# 1                                            1
# 2                                            1
# 3                                           15
# 4                                            0
#
#    calculated_host_listings_count_private_rooms  \
# 0                                             0
# 1                                             2
# 2                                             0
# 3                                             0
# 4                                             2
#
#    calculated_host_listings_count_shared_rooms  \
# 0                                            0
# 1                                            0
# 2                                            0
# 3                                            0
# 4                                            0
#
#                          host_location  host_since  \
# 0      London, England, United Kingdom  2009-10-03
# 1      London, England, United Kingdom  2009-11-16
# 2  Kensington, England, United Kingdom  2009-12-05
# 3      London, England, United Kingdom  2010-01-04
# 4      London, England, United Kingdom  2010-01-05
#
#                                       street       city security_deposit  \
# 0                     London, United Kingdom     London          $400.00
# 1  Islington, Greater London, United Kingdom  Islington          $100.00
# 2                     London, United Kingdom     London          $150.00
# 3          London, Fitzrovia, United Kingdom     London          $350.00
# 4                     London, United Kingdom     London              NaN
#
#   cleaning_fee     id
# 0       $35.00  11551
# 1       $15.00  13913
# 2       $50.00  15400
# 3       $90.00  17402
# 4          NaN  17506

# %%
df.shape
# Out:
# (83709, 42)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 83709 entries, 0 to 83708
# Data columns (total 42 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   Unnamed: 0                                    83709 non-null  int64
#  1   price_x                                       83709 non-null  int64
#  2   experiences_offered                           83709 non-null  object
#  3   host_is_superhost                             83698 non-null  object
#  4   host_listings_count                           83698 non-null  float64
#  5   host_has_profile_pic                          83698 non-null  object
#  6   host_identity_verified                        83698 non-null  object
#  7   is_location_exact                             83709 non-null  object
#  8   property_type                                 83709 non-null  object
#  9   room_type_y                                   83709 non-null  object
#  10  accommodates                                  83709 non-null  int64
#  11  bathrooms                                     83576 non-null  float64
#  12  bedrooms                                      83545 non-null  float64
#  13  beds                                          82725 non-null  float64
#  14  bed_type                                      83706 non-null  object
#  15  guests_included                               83709 non-null  int64
#  16  extra_people                                  83709 non-null  float64
#  17  minimum_nights_y                              83709 non-null  int64
#  18  maximum_nights                                83709 non-null  int64
#  19  availability_30                               83709 non-null  int64
#  20  availability_60                               83709 non-null  int64
#  21  availability_90                               83709 non-null  int64
#  22  availability_365_y                            83709 non-null  int64
#  23  number_of_reviews_y                           83709 non-null  int64
#  24  number_of_reviews_ltm                         83709 non-null  int64
#  25  requires_license                              83709 non-null  object
#  26  instant_bookable                              83709 non-null  object
#  27  is_business_travel_ready                      83709 non-null  object
#  28  cancellation_policy                           83709 non-null  object
#  29  require_guest_profile_picture                 83709 non-null  object
#  30  require_guest_phone_verification              83709 non-null  object
#  31  calculated_host_listings_count_y              83709 non-null  int64
#  32  calculated_host_listings_count_entire_homes   83709 non-null  int64
#  33  calculated_host_listings_count_private_rooms  83709 non-null  int64
#  34  calculated_host_listings_count_shared_rooms   83709 non-null  int64
#  35  host_location                                 83501 non-null  object
#  36  host_since                                    83698 non-null  object
#  37  street                                        83709 non-null  object
#  38  city                                          83256 non-null  object
#  39  security_deposit                              54179 non-null  object
#  40  cleaning_fee                                  61607 non-null  object
#  41  id                                            83709 non-null  int64
# dtypes: float64(5), int64(17), object(20)
# memory usage: 26.8+ MB

# %%
df.describe()
# Out:
#          Unnamed: 0       price_x  host_listings_count  accommodates  \
# count  83709.000000  83709.000000         83698.000000  83709.000000
# mean   41854.942360    127.521664            25.969904      3.173482
# std    24165.694388    282.327202           145.825064      2.013219
# min        0.000000      0.000000             0.000000      1.000000
# 25%    20927.000000     46.000000             1.000000      2.000000
# 50%    41855.000000     81.000000             1.000000      2.000000
# 75%    62783.000000    139.000000             4.000000      4.000000
# max    83710.000000  19970.000000          3142.000000     32.000000
#
#           bathrooms      bedrooms          beds  guests_included  \
# count  83576.000000  83545.000000  82725.000000     83709.000000
# mean       1.308210      1.408965      1.739909         1.607032
# std        0.621894      0.933268      1.295726         1.364971
# min        0.000000      0.000000      0.000000         1.000000
# 25%        1.000000      1.000000      1.000000         1.000000
# 50%        1.000000      1.000000      1.000000         1.000000
# 75%        1.500000      2.000000      2.000000         2.000000
# max       35.000000     50.000000     50.000000        46.000000
#
#        extra_people  minimum_nights_y  maximum_nights  availability_30  \
# count  83709.000000      83709.000000    8.370900e+04     83709.000000
# mean       7.392873          4.632250    1.915622e+04         4.906868
# std       14.303404         19.800467    3.903712e+06         5.507494
# min        0.000000          1.000000    1.000000e+00         0.000000
# 25%        0.000000          1.000000    3.100000e+01         0.000000
# 50%        0.000000          2.000000    1.125000e+03         0.000000
# 75%       10.000000          3.000000    1.125000e+03        11.000000
# max      247.000000       1125.000000    1.000000e+09        30.000000
#
#        availability_60  availability_90  availability_365_y  \
# count     83709.000000     83709.000000        83709.000000
# mean         18.481274        32.513254          117.366651
# std          19.399954        33.136850          136.115257
# min           0.000000         0.000000            0.000000
# 25%           0.000000         0.000000            0.000000
# 50%           7.000000        16.000000           69.000000
# 75%          40.000000        70.000000          249.000000
# max          60.000000        90.000000          365.000000
#
#        number_of_reviews_y  number_of_reviews_ltm  \
# count         83709.000000           83709.000000
# mean             16.904718               4.750397
# std              36.606916               9.671885
# min               0.000000               0.000000
# 25%               0.000000               0.000000
# 50%               4.000000               1.000000
# 75%              17.000000               5.000000
# max             775.000000             334.000000
#
#        calculated_host_listings_count_y  \
# count                      83709.000000
# mean                          19.587058
# std                           99.471139
# min                            1.000000
# 25%                            1.000000
# 50%                            1.000000
# 75%                            4.000000
# max                          921.000000
#
#        calculated_host_listings_count_entire_homes  \
# count                                 83709.000000
# mean                                     16.756143
# std                                      97.734106
# min                                       0.000000
# 25%                                       0.000000
# 50%                                       1.000000
# 75%                                       2.000000
# max                                     919.000000
#
#        calculated_host_listings_count_private_rooms  \
# count                                  83709.000000
# mean                                       2.166482
# std                                       12.728904
# min                                        0.000000
# 25%                                        0.000000
# 50%                                        1.000000
# 75%                                        1.000000
# max                                      223.000000
#
#        calculated_host_listings_count_shared_rooms            id
# count                                 83709.000000  8.370900e+04
# mean                                      0.051333  2.502263e+07
# std                                       0.704368  1.249012e+07
# min                                       0.000000  1.155100e+04
# 25%                                       0.000000  1.522811e+07
# 50%                                       0.000000  2.546694e+07
# 75%                                       0.000000  3.651236e+07
# max                                      18.000000  4.375172e+07

# %% [markdown]
# ### Dropping Unique Columns

# %%
df.drop(['Unnamed: 0','id'],axis=1,inplace=True)

# %% [markdown]
# ### Dropping columns having a single class

# %%
df.drop(['requires_license','is_business_travel_ready'],axis=1,inplace=True)

# %% [markdown]
# ### Dropping columns with missing values more than 70%

# %%
print(df['calculated_host_listings_count_shared_rooms'].value_counts()[0]/df.shape[0])
df.drop('calculated_host_listings_count_shared_rooms',axis=1,inplace=True)
# Out:
# 0.9857482469029615

# %% [markdown]
# ### Cleaning improper data

# %%
df['cleaning_fee']=df['cleaning_fee'].astype('str')
x=df['cleaning_fee'].to_list()
for i in range(len(x)):
    x[i]=x[i].strip('$')
    x[i]=x[i].replace(',','')
    if x[i]=='nan'or x[i]=='NaN':
        x[i]=np.nan
df['cleaning_fee']=pd.DataFrame(x)        
df['cleaning_fee']=pd.to_numeric(df['cleaning_fee'])

# %%
df['security_deposit']=df['security_deposit'].astype('str')
x=df['security_deposit'].to_list()
for i in range(len(x)):
    x[i]=x[i].strip('$')
    x[i]=x[i].replace(',','')
    if x[i]=='nan'or x[i]=='NaN':
        x[i]=np.nan
df['security_deposit']=pd.DataFrame(x)        
df['security_deposit']=pd.to_numeric(df['security_deposit'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 83709 entries, 0 to 83708
# Data columns (total 37 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   price_x                                       83709 non-null  int64
#  1   experiences_offered                           83709 non-null  object
#  2   host_is_superhost                             83698 non-null  object
#  3   host_listings_count                           83698 non-null  float64
#  4   host_has_profile_pic                          83698 non-null  object
#  5   host_identity_verified                        83698 non-null  object
#  6   is_location_exact                             83709 non-null  object
#  7   property_type                                 83709 non-null  object
#  8   room_type_y                                   83709 non-null  object
#  9   accommodates                                  83709 non-null  int64
#  10  bathrooms                                     83576 non-null  float64
#  11  bedrooms                                      83545 non-null  float64
#  12  beds                                          82725 non-null  float64
#  13  bed_type                                      83706 non-null  object
#  14  guests_included                               83709 non-null  int64
#  15  extra_people                                  83709 non-null  float64
#  16  minimum_nights_y                              83709 non-null  int64
#  17  maximum_nights                                83709 non-null  int64
#  18  availability_30                               83709 non-null  int64
#  19  availability_60                               83709 non-null  int64
#  20  availability_90                               83709 non-null  int64
#  21  availability_365_y                            83709 non-null  int64
#  22  number_of_reviews_y                           83709 non-null  int64
#  23  number_of_reviews_ltm                         83709 non-null  int64
#  24  instant_bookable                              83709 non-null  object
#  25  cancellation_policy                           83709 non-null  object
#  26  require_guest_profile_picture                 83709 non-null  object
#  27  require_guest_phone_verification              83709 non-null  object
#  28  calculated_host_listings_count_y              83709 non-null  int64
#  29  calculated_host_listings_count_entire_homes   83709 non-null  int64
#  30  calculated_host_listings_count_private_rooms  83709 non-null  int64
#  31  host_location                                 83501 non-null  object
#  32  host_since                                    83698 non-null  object
#  33  street                                        83709 non-null  object
#  34  city                                          83256 non-null  object
#  35  security_deposit                              54179 non-null  float64
#  36  cleaning_fee                                  61607 non-null  float64
# dtypes: float64(7), int64(14), object(16)
# memory usage: 23.6+ MB

# %%
num_cols=df.select_dtypes(include=['int64','float64']).columns
cat_cols=df.select_dtypes(include='object').columns
num_cols,cat_cols
# Out:
# (Index(['price_x', 'host_listings_count', 'accommodates', 'bathrooms',
#         'bedrooms', 'beds', 'guests_included', 'extra_people',
#         'minimum_nights_y', 'maximum_nights', 'availability_30',
#         'availability_60', 'availability_90', 'availability_365_y',
#         'number_of_reviews_y', 'number_of_reviews_ltm',
#         'calculated_host_listings_count_y',
#         'calculated_host_listings_count_entire_homes',
#         'calculated_host_listings_count_private_rooms', 'security_deposit',
#         'cleaning_fee'],
#        dtype='object'),
#  Index(['experiences_offered', 'host_is_superhost', 'host_has_profile_pic',
#         'host_identity_verified', 'is_location_exact', 'property_type',
#         'room_type_y', 'bed_type', 'instant_bookable', 'cancellation_policy',
#         'require_guest_profile_picture', 'require_guest_phone_verification',
#         'host_location', 'host_since', 'street', 'city'],
#        dtype='object'))

# %% [markdown]
# ### Finding Null columns

# %%
num_null_cols=[]
cat_null_cols=[]
for i in num_cols:
    if df[i].isnull().sum()>0:
        num_null_cols.append(i)
for i in cat_cols:
    if df[i].isnull().sum()>0:
        cat_null_cols.append(i)
num_null_cols,cat_null_cols
# Out:
# (['host_listings_count',
#   'bathrooms',
#   'bedrooms',
#   'beds',
#   'security_deposit',
#   'cleaning_fee'],
#  ['host_is_superhost',
#   'host_has_profile_pic',
#   'host_identity_verified',
#   'bed_type',
#   'host_location',
#   'host_since',
#   'city'])

# %% [markdown]
# ### Finding outlier columns

# %%
outlier_cols=[]
for i in num_cols:
    iqr=df[i].quantile(0.75)-df[i].quantile(0.25)
    higher_range=df[i].quantile(0.75)+(1.5*iqr)
    lower_range=df[i].quantile(0.25)-(1.5*iqr)
    if df[i][df[i]<lower_range].count()>0 or df[i][df[i]>higher_range].count()>0:
        outlier_cols.append(i)
outlier_cols
# Out:
# ['price_x',
#  'host_listings_count',
#  'accommodates',
#  'bathrooms',
#  'bedrooms',
#  'beds',
#  'guests_included',
#  'extra_people',
#  'minimum_nights_y',
#  'maximum_nights',
#  'availability_30',
#  'number_of_reviews_y',
#  'number_of_reviews_ltm',
#  'calculated_host_listings_count_y',
#  'calculated_host_listings_count_entire_homes',
#  'calculated_host_listings_count_private_rooms',
#  'security_deposit',
#  'cleaning_fee']

# %% [markdown]
# ### Numerical Null Imputation

# %%
for i in num_null_cols:
    if i in outlier_cols:
        df[i]=df[i].fillna(df[i].median())
    else:
        df[i]=df[i].fillna(df[i].mean())

# %%
for i in num_null_cols:
    if df[i].isnull().sum()>0:
        print(True)
    else:
        print(False)
# Out:
# False
# False
# False
# False
# False
# False

# %% [markdown]
# ### Categorical Null Imputation

# %%
for i in cat_null_cols:
    df[i]=df[i].fillna(df[i].mode()[0])

# %%
for i in cat_null_cols:
    if df[i].isnull().sum()>0:
        print(True)
    else:
        print(False)
# Out:
# False
# False
# False
# False
# False
# False
# False

# %%
df[outlier_cols]
# Out:
#        price_x  host_listings_count  accommodates  bathrooms  bedrooms  beds  \
# 0           88                  3.0             4        1.0       1.0   3.0
# 1           65                  4.0             2        1.0       1.0   0.0
# 2          100                  1.0             2        1.0       1.0   1.0
# 3          300                 18.0             6        2.0       3.0   3.0
# 4          150                  3.0             2        1.0       1.0   1.0
# ...        ...                  ...           ...        ...       ...   ...
# 83704       28                  1.0            11        6.0      10.0  11.0
# 83705     1880                144.0             6        1.0       2.0   3.0
# 83706       66                  1.0             4        1.0       1.0   2.0
# 83707       69                  2.0             2        1.0       1.0   2.0
# 83708       55                  2.0             1        1.0       1.0   1.0
#
#        guests_included  extra_people  minimum_nights_y  maximum_nights  \
# 0                    2          20.0                 2             180
# 1                    1          15.0                 1              29
# 2                    2           0.0                10              50
# 3                    3          10.0                 3             365
# 4                    1           0.0                 3              21
# ...                ...           ...               ...             ...
# 83704                1           0.0                 1              90
# 83705                3          15.0                 1            1125
# 83706                1           0.0                 3            1125
# 83707                1          25.0                 7              60
# 83708                1          25.0                29              61
#
#        availability_30  number_of_reviews_y  number_of_reviews_ltm  \
# 0                   12                  192                      9
# 1                   12                   21                      5
# 2                    0                   89                      4
# 3                    9                   42                      2
# 4                   11                    0                      0
# ...                ...                  ...                    ...
# 83704               11                    0                      0
# 83705               12                    0                      0
# 83706               13                    0                      0
# 83707                8                    0                      0
# 83708               11                    0                      0
#
#        calculated_host_listings_count_y  \
# 0                                     2
# 1                                     3
# 2                                     1
# 3                                    15
# 4                                     2
# ...                                 ...
# 83704                                 1
# 83705                                30
# 83706                                 1
# 83707                                 1
# 83708                                 2
#
#        calculated_host_listings_count_entire_homes  \
# 0                                                2
# 1                                                1
# 2                                                1
# 3                                               15
# 4                                                0
# ...                                            ...
# 83704                                            0
# 83705                                           30
# 83706                                            1
# 83707                                            0
# 83708                                            1
#
#        calculated_host_listings_count_private_rooms  security_deposit  \
# 0                                                 0             400.0
# 1                                                 2             100.0
# 2                                                 0             150.0
# 3                                                 0             350.0
# 4                                                 2             100.0
# ...                                             ...               ...
# 83704                                             1             456.0
# 83705                                             0               0.0
# 83706                                             0             250.0
# 83707                                             1             100.0
# 83708                                             1             100.0
#
#        cleaning_fee
# 0              35.0
# 1              15.0
# 2              50.0
# 3              90.0
# 4              30.0
# ...             ...
# 83704          25.0
# 83705         125.0
# 83706          70.0
# 83707          19.0
# 83708          30.0
#
# [83709 rows x 18 columns]

# %% [markdown]
# ### Outlier Imputation

# %%
for i in outlier_cols:
    iqr=df[i].quantile(0.75)-df[i].quantile(0.25)
    higher_range=df[i].quantile(0.75)+(1.5*iqr)
    lower_range=df[i].quantile(0.25)-(1.5*iqr)
    replace_higher_value=df[i].quantile(0.9)
    replace_lower_value=df[i].quantile(0.1)
    outlier_treated=np.where(df[i]>higher_range,replace_higher_value,df[i])
    df[i]=pd.DataFrame(outlier_treated)
    outlier_treated=np.where(df[i]<lower_range,replace_lower_value,df[i])
    df[i]=pd.DataFrame(outlier_treated)

# %%
df[outlier_cols]
# Out:
#        price_x  host_listings_count  accommodates  bathrooms  bedrooms  beds  \
# 0         88.0                  3.0           4.0        1.0       1.0   3.0
# 1         65.0                  4.0           2.0        1.0       1.0   0.0
# 2        100.0                  1.0           2.0        1.0       1.0   1.0
# 3        225.0                 26.0           6.0        2.0       3.0   3.0
# 4        150.0                  3.0           2.0        1.0       1.0   1.0
# ...        ...                  ...           ...        ...       ...   ...
# 83704     28.0                  1.0           6.0        2.0       3.0   3.0
# 83705    225.0                 26.0           6.0        1.0       2.0   3.0
# 83706     66.0                  1.0           4.0        1.0       1.0   2.0
# 83707     69.0                  2.0           2.0        1.0       1.0   2.0
# 83708     55.0                  2.0           1.0        1.0       1.0   1.0
#
#        guests_included  extra_people  minimum_nights_y  maximum_nights  \
# 0                  2.0          20.0               2.0           180.0
# 1                  1.0          15.0               1.0            29.0
# 2                  2.0           0.0               7.0            50.0
# 3                  3.0          10.0               3.0           365.0
# 4                  1.0           0.0               3.0            21.0
# ...                ...           ...               ...             ...
# 83704              1.0           0.0               1.0            90.0
# 83705              3.0          15.0               1.0          1125.0
# 83706              1.0           0.0               3.0          1125.0
# 83707              1.0          25.0               7.0            60.0
# 83708              1.0          25.0               7.0            61.0
#
#        availability_30  number_of_reviews_y  number_of_reviews_ltm  \
# 0                 12.0                 45.0                    9.0
# 1                 12.0                 21.0                    5.0
# 2                  0.0                 45.0                    4.0
# 3                  9.0                 42.0                    2.0
# 4                 11.0                  0.0                    0.0
# ...                ...                  ...                    ...
# 83704             11.0                  0.0                    0.0
# 83705             12.0                  0.0                    0.0
# 83706             13.0                  0.0                    0.0
# 83707              8.0                  0.0                    0.0
# 83708             11.0                  0.0                    0.0
#
#        calculated_host_listings_count_y  \
# 0                                   2.0
# 1                                   3.0
# 2                                   1.0
# 3                                  23.0
# 4                                   2.0
# ...                                 ...
# 83704                               1.0
# 83705                              23.0
# 83706                               1.0
# 83707                               1.0
# 83708                               2.0
#
#        calculated_host_listings_count_entire_homes  \
# 0                                              2.0
# 1                                              1.0
# 2                                              1.0
# 3                                             18.0
# 4                                              0.0
# ...                                            ...
# 83704                                          0.0
# 83705                                         18.0
# 83706                                          1.0
# 83707                                          0.0
# 83708                                          1.0
#
#        calculated_host_listings_count_private_rooms  security_deposit  \
# 0                                               0.0             350.0
# 1                                               2.0             100.0
# 2                                               0.0             150.0
# 3                                               0.0             350.0
# 4                                               2.0             100.0
# ...                                             ...               ...
# 83704                                           1.0             350.0
# 83705                                           0.0               0.0
# 83706                                           0.0             250.0
# 83707                                           1.0             100.0
# 83708                                           1.0             100.0
#
#        cleaning_fee
# 0              35.0
# 1              15.0
# 2              50.0
# 3              90.0
# 4              30.0
# ...             ...
# 83704          25.0
# 83705          80.0
# 83706          70.0
# 83707          19.0
# 83708          30.0
#
# [83709 rows x 18 columns]

# %%
new_outlier_cols=[]
for i in outlier_cols:
    iqr=df[i].quantile(0.75)-df[i].quantile(0.25)
    higher_range=df[i].quantile(0.75)+(1.5*iqr)
    lower_range=df[i].quantile(0.25)-(1.5*iqr)
    if df[i][df[i]<lower_range].count()>0 or df[i][df[i]>higher_range].count()>0:
        new_outlier_cols.append(i)
        print(True,i)
    else:
        print(False)
new_outlier_cols
# Out:
# False
# True host_listings_count
# False
# False
# False
# False
# True guests_included
# False
# True minimum_nights_y
# False
# False
# True number_of_reviews_y
# True number_of_reviews_ltm
# True calculated_host_listings_count_y
# True calculated_host_listings_count_entire_homes
# True calculated_host_listings_count_private_rooms
# False
# False
# ['host_listings_count',
#  'guests_included',
#  'minimum_nights_y',
#  'number_of_reviews_y',
#  'number_of_reviews_ltm',
#  'calculated_host_listings_count_y',
#  'calculated_host_listings_count_entire_homes',
#  'calculated_host_listings_count_private_rooms']

# %%
for i in new_outlier_cols:
    iqr=df[i].quantile(0.75)-df[i].quantile(0.25)
    higher_range=df[i].quantile(0.75)+(1.5*iqr)
    lower_range=df[i].quantile(0.25)-(1.5*iqr)
    replace_higher_value=df[i].quantile(0.8)
    replace_lower_value=df[i].quantile(0.2)
    outlier_treated=np.where(df[i]>higher_range,replace_higher_value,df[i])
    df[i]=pd.DataFrame(outlier_treated)
    outlier_treated=np.where(df[i]<lower_range,replace_lower_value,df[i])
    df[i]=pd.DataFrame(outlier_treated)

# %%
for i in new_outlier_cols:
    iqr=df[i].quantile(0.75)-df[i].quantile(0.25)
    higher_range=df[i].quantile(0.75)+(1.5*iqr)
    lower_range=df[i].quantile(0.25)-(1.5*iqr)
    if df[i][df[i]<lower_range].count()>0 or df[i][df[i]>higher_range].count()>0:        
        print(True,i)
    else:
        print(False)
# Out:
# False
# False
# False
# False
# False
# False
# False
# False

# %% [markdown]
# ### Encoding

# %%
for i in cat_cols:
    if df[i].value_counts().count()<3:
        df[i]=df[i].map({'t':1,'f':0})   
    else:
        df[i]=LabelEncoder().fit_transform(df[i])

# %%
for i in cat_cols:
    print(df[i].value_counts())
    print('----------------------------------')
# Out:
# 2    82170
# 0      524
# 1      450
# 4      367
# 3      198
# Name: experiences_offered, dtype: int64
# ----------------------------------
# 0    71165
# 1    12544
# Name: host_is_superhost, dtype: int64
# ----------------------------------
# 1    83388
# 0      321
# Name: host_has_profile_pic, dtype: int64
# ----------------------------------
# 0    54908
# 1    28801
# Name: host_identity_verified, dtype: int64
# ----------------------------------
# 1    57239
# 0    26470
# Name: is_location_exact, dtype: int64
# ----------------------------------
# 1     55572
# 23    17851
# 36     2817
# 14     2161
# 32     1441
# 28      748
# 3       600
# 5       403
# 19      382
# 20      316
# 21      272
# 22      252
# 30      213
# 6       167
# 15       89
# 35       69
# 0        68
# 4        65
# 38       50
# 24       36
# 8        25
# 17       20
# 9        16
# 13       14
# 25       11
# 2         7
# 40        7
# 18        7
# 11        6
# 12        3
# 10        3
# 16        3
# 34        3
# 37        3
# 27        2
# 26        2
# 31        1
# 29        1
# 7         1
# 33        1
# 39        1
# Name: property_type, dtype: int64
# ----------------------------------
# 0    46711
# 2    35591
# 1      745
# 3      662
# Name: room_type_y, dtype: int64
# ----------------------------------
# 4    83103
# 3      351
# 2      154
# 1       60
# 0       41
# Name: bed_type, dtype: int64
# ----------------------------------
# 0    48022
# 1    35687
# Name: instant_bookable, dtype: int64
# ----------------------------------
# 5    33696
# 0    28859
# 3    20707
# 6      258
# 7      151
# 1       27
# 4        6
# 2        5
# Name: cancellation_policy, dtype: int64
# ----------------------------------
# 0    82924
# 1      785
# Name: require_guest_profile_picture, dtype: int64
# ----------------------------------
# 0    82409
# 1     1300
# Name: require_guest_phone_verification, dtype: int64
# ----------------------------------
# 1354    34926
# 807     10884
# 723     10813
# 1265     7007
# 1381     6877
#         ...
# 1829        1
# 1893        1
# 1957        1
# 2021        1
# 0           1
# Name: host_location, Length: 2513, dtype: int64
# ----------------------------------
# 1820    964
# 1987    317
# 1743    283
# 1399    271
# 545     197
#        ...
# 71        1
# 199       1
# 52        1
# 478       1
# 229       1
# Name: host_since, Length: 3664, dtype: int64
# ----------------------------------
# 329     46748
# 717     13806
# 853     13211
# 733      1696
# 783      1074
#         ...
# 421         1
# 357         1
# 165         1
# 1380        1
# 0           1
# Name: street, Length: 1432, dtype: int64
# ----------------------------------
# 223    47784
# 355    30454
# 356      783
# 631      168
# 143      164
#        ...
# 611        1
# 675        1
# 36         1
# 292        1
# 0          1
# Name: city, Length: 729, dtype: int64
# ----------------------------------

# %%
df.head()
# Out:
#    price_x  experiences_offered  host_is_superhost  host_listings_count  \
# 0     88.0                    1                  0                  3.0
# 1     65.0                    0                  0                  4.0
# 2    100.0                    3                  0                  1.0
# 3    225.0                    2                  0                  7.0
# 4    150.0                    0                  0                  3.0
#
#    host_has_profile_pic  host_identity_verified  is_location_exact  \
# 0                     1                       1                  1
# 1                     1                       1                  1
# 2                     1                       1                  1
# 3                     1                       1                  0
# 4                     1                       0                  1
#
#    property_type  room_type_y  accommodates  bathrooms  bedrooms  beds  \
# 0              1            0           4.0        1.0       1.0   3.0
# 1              1            2           2.0        1.0       1.0   0.0
# 2              1            0           2.0        1.0       1.0   1.0
# 3              1            0           6.0        2.0       3.0   3.0
# 4              3            2           2.0        1.0       1.0   1.0
#
#    bed_type  guests_included  extra_people  minimum_nights_y  maximum_nights  \
# 0         4              2.0          20.0               2.0           180.0
# 1         4              1.0          15.0               1.0            29.0
# 2         4              2.0           0.0               4.0            50.0
# 3         4              3.0          10.0               3.0           365.0
# 4         4              1.0           0.0               3.0            21.0
#
#    availability_30  availability_60  availability_90  availability_365_y  \
# 0             12.0               42               72                 347
# 1             12.0               42               72                 347
# 2              0.0                0               13                 288
# 3              9.0               39               69                 326
# 4             11.0               41               71                 346
#
#    number_of_reviews_y  number_of_reviews_ltm  instant_bookable  \
# 0                 22.0                    9.0                 1
# 1                 21.0                    5.0                 0
# 2                 22.0                    4.0                 1
# 3                 42.0                    2.0                 1
# 4                  0.0                    0.0                 0
#
#    cancellation_policy  require_guest_profile_picture  \
# 0                    5                              0
# 1                    3                              0
# 2                    5                              1
# 3                    5                              0
# 4                    5                              0
#
#    require_guest_phone_verification  calculated_host_listings_count_y  \
# 0                                 1                               2.0
# 1                                 0                               3.0
# 2                                 1                               1.0
# 3                                 0                               7.0
# 4                                 0                               2.0
#
#    calculated_host_listings_count_entire_homes  \
# 0                                          2.0
# 1                                          1.0
# 2                                          1.0
# 3                                          3.0
# 4                                          0.0
#
#    calculated_host_listings_count_private_rooms  host_location  host_since  \
# 0                                           0.0           1354          36
# 1                                           2.0           1354          44
# 2                                           0.0           1100          50
# 3                                           0.0           1354          57
# 4                                           2.0           1354          58
#
#    street  city  security_deposit  cleaning_fee
# 0     853   355             350.0          35.0
# 1     481   306             100.0          15.0
# 2     853   355             150.0          50.0
# 3     720   355             350.0          90.0
# 4     853   355             100.0          30.0

# %% [markdown]
# ### OLS summary

# %%
df.shape
# Out:
# (83709, 37)

# %%
df.corr().iloc[:,[0]]
# Out:
#                                                price_x
# price_x                                       1.000000
# experiences_offered                          -0.030623
# host_is_superhost                            -0.036899
# host_listings_count                           0.275605
# host_has_profile_pic                          0.010001
# host_identity_verified                       -0.029702
# is_location_exact                             0.014255
# property_type                                -0.042460
# room_type_y                                  -0.609265
# accommodates                                  0.652127
# bathrooms                                     0.365231
# bedrooms                                      0.542011
# beds                                          0.539217
# bed_type                                      0.042883
# guests_included                               0.285368
# extra_people                                  0.024262
# minimum_nights_y                              0.164632
# maximum_nights                                0.145782
# availability_30                               0.047802
# availability_60                               0.084899
# availability_90                               0.088515
# availability_365_y                            0.141785
# number_of_reviews_y                          -0.056866
# number_of_reviews_ltm                        -0.012055
# instant_bookable                              0.046504
# cancellation_policy                           0.208544
# require_guest_profile_picture                -0.010089
# require_guest_phone_verification              0.035097
# calculated_host_listings_count_y              0.290488
# calculated_host_listings_count_entire_homes   0.516754
# calculated_host_listings_count_private_rooms -0.387459
# host_location                                -0.007149
# host_since                                    0.022341
# street                                       -0.014549
# city                                         -0.022382
# security_deposit                              0.342234
# cleaning_fee                                  0.511700

# %% [markdown]
# ### Dropping columns which is having very less correlation wrt target column

# %%
df.drop('host_location',axis=1,inplace=True)

# %%
inputs=df.drop('price_x',axis=1).values
outputs=df[['price_x']].values
inputs,outputs
# Out:
# (array([[  1.,   0.,   3., ..., 355., 350.,  35.],
#         [  0.,   0.,   4., ..., 306., 100.,  15.],
#         [  3.,   0.,   1., ..., 355., 150.,  50.],
#         ...,
#         [  2.,   0.,   1., ..., 223., 250.,  70.],
#         [  2.,   0.,   2., ..., 223., 100.,  19.],
#         [  2.,   1.,   2., ..., 223., 100.,  30.]]),
#  array([[ 88.],
#         [ 65.],
#         [100.],
#         ...,
#         [ 66.],
#         [ 69.],
#         [ 55.]]))

# %%
inputs.shape
# Out:
# (83709, 35)

# %%
intercept = np.ones((inputs.shape[0],1))
inputs = np.delete(inputs,13,axis=1) #12,8
inputs = np.hstack([intercept,inputs])


model = sm.OLS(outputs,inputs).fit()

model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.583
# Model:                            OLS   Adj. R-squared:                  0.583
# Method:                 Least Squares   F-statistic:                     3442.
# Date:                Thu, 05 May 2022   Prob (F-statistic):               0.00
# Time:                        20:21:52   Log-Likelihood:            -4.3089e+05
# No. Observations:               83709   AIC:                         8.619e+05
# Df Residuals:                   83674   BIC:                         8.622e+05
# Df Model:                          34
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         17.3932      1.479     11.763      0.000      14.495      20.291
# x1            17.3932      1.479     11.763      0.000      14.495      20.291
# x2            -2.2591      0.643     -3.511      0.000      -3.520      -0.998
# x3             7.1943      0.450     15.996      0.000       6.313       8.076
# x4             0.6705      0.142      4.734      0.000       0.393       0.948
# x5            -1.0080      2.334     -0.432      0.666      -5.583       3.567
# x6            -2.6634      0.333     -7.989      0.000      -3.317      -2.010
# x7             0.8411      0.313      2.688      0.007       0.228       1.454
# x8            -0.0460      0.014     -3.336      0.001      -0.073      -0.019
# x9           -17.2071      0.286    -60.238      0.000     -17.767     -16.647
# x10            8.6844      0.187     46.558      0.000       8.319       9.050
# x11           13.1988      0.429     30.734      0.000      12.357      14.040
# x12           12.8399      0.333     38.572      0.000      12.187      13.492
# x13            0.0223      0.304      0.073      0.942      -0.573       0.617
# x14            1.5892      0.365      4.359      0.000       0.875       2.304
# x15           -0.4042      0.021    -19.394      0.000      -0.445      -0.363
# x16           -1.0518      0.121     -8.661      0.000      -1.290      -0.814
# x17            0.0019      0.000      6.718      0.000       0.001       0.003
# x18           -1.4894      0.096    -15.553      0.000      -1.677      -1.302
# x19            0.7040      0.064     10.918      0.000       0.578       0.830
# x20           -0.0815      0.031     -2.654      0.008      -0.142      -0.021
# x21            0.0328      0.002     19.731      0.000       0.030       0.036
# x22           -0.3826      0.020    -19.566      0.000      -0.421      -0.344
# x23           -0.7251      0.062    -11.725      0.000      -0.846      -0.604
# x24            4.1606      0.315     13.224      0.000       3.544       4.777
# x25            0.4683      0.074      6.335      0.000       0.323       0.613
# x26           -4.9494      2.005     -2.469      0.014      -8.878      -1.020
# x27            4.9565      1.589      3.120      0.002       1.843       8.070
# x28            1.9878      0.170     11.687      0.000       1.654       2.321
# x29            0.9454      0.256      3.696      0.000       0.444       1.447
# x30           -4.8016      0.302    -15.912      0.000      -5.393      -4.210
# x31            0.0010      0.000      4.989      0.000       0.001       0.001
# x32            0.0160      0.002      7.362      0.000       0.012       0.020
# x33           -0.0325      0.006     -5.144      0.000      -0.045      -0.020
# x34            0.0464      0.002     30.681      0.000       0.043       0.049
# x35            0.2671      0.008     33.679      0.000       0.252       0.283
# ==============================================================================
# Omnibus:                    12428.494   Durbin-Watson:                   1.807
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            26571.384
# Skew:                           0.894   Prob(JB):                         0.00
# Kurtosis:                       5.103   Cond. No.                     3.51e+15
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 3.84e-20. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# """

# %%
intercept = np.ones((inputs.shape[0],1))
inputs = np.delete(inputs,14,axis=1) #12,8
inputs = np.hstack([intercept,inputs])


model = sm.OLS(outputs,inputs).fit()

model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.583
# Model:                            OLS   Adj. R-squared:                  0.583
# Method:                 Least Squares   F-statistic:                     3545.
# Date:                Thu, 05 May 2022   Prob (F-statistic):               0.00
# Time:                        20:22:37   Log-Likelihood:            -4.3090e+05
# No. Observations:               83709   AIC:                         8.619e+05
# Df Residuals:                   83675   BIC:                         8.622e+05
# Df Model:                          33
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         12.1159      0.979     12.381      0.000      10.198      14.034
# x1            12.1159      0.979     12.381      0.000      10.198      14.034
# x2            12.1159      0.979     12.381      0.000      10.198      14.034
# x3            -2.2484      0.644     -3.494      0.000      -3.510      -0.987
# x4             7.1553      0.450     15.911      0.000       6.274       8.037
# x5             0.6885      0.142      4.863      0.000       0.411       0.966
# x6            -1.0421      2.335     -0.446      0.655      -5.618       3.534
# x7            -2.6932      0.333     -8.079      0.000      -3.347      -2.040
# x8             0.8426      0.313      2.692      0.007       0.229       1.456
# x9            -0.0467      0.014     -3.382      0.001      -0.074      -0.020
# x10          -17.3164      0.285    -60.848      0.000     -17.874     -16.759
# x11            8.7582      0.186     47.144      0.000       8.394       9.122
# x12           13.1154      0.429     30.567      0.000      12.274      13.956
# x13           12.8000      0.333     38.463      0.000      12.148      13.452
# x14            0.0732      0.303      0.241      0.809      -0.522       0.668
# x15           -0.3642      0.019    -19.460      0.000      -0.401      -0.328
# x16           -1.0675      0.121     -8.793      0.000      -1.305      -0.830
# x17            0.0020      0.000      6.879      0.000       0.001       0.003
# x18           -1.4875      0.096    -15.531      0.000      -1.675      -1.300
# x19            0.7025      0.064     10.894      0.000       0.576       0.829
# x20           -0.0815      0.031     -2.655      0.008      -0.142      -0.021
# x21            0.0328      0.002     19.740      0.000       0.030       0.036
# x22           -0.3808      0.020    -19.477      0.000      -0.419      -0.342
# x23           -0.7205      0.062    -11.650      0.000      -0.842      -0.599
# x24            4.2025      0.315     13.362      0.000       3.586       4.819
# x25            0.4845      0.074      6.561      0.000       0.340       0.629
# x26           -5.1288      2.004     -2.559      0.011      -9.057      -1.200
# x27            5.1229      1.588      3.225      0.001       2.010       8.236
# x28            1.9886      0.170     11.690      0.000       1.655       2.322
# x29            0.9702      0.256      3.794      0.000       0.469       1.471
# x30           -4.7853      0.302    -15.857      0.000      -5.377      -4.194
# x31            0.0011      0.000      5.052      0.000       0.001       0.001
# x32            0.0166      0.002      7.631      0.000       0.012       0.021
# x33           -0.0337      0.006     -5.342      0.000      -0.046      -0.021
# x34            0.0464      0.002     30.654      0.000       0.043       0.049
# x35            0.2705      0.008     34.281      0.000       0.255       0.286
# ==============================================================================
# Omnibus:                    12464.748   Durbin-Watson:                   1.806
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            26676.859
# Skew:                           0.896   Prob(JB):                         0.00
# Kurtosis:                       5.107   Cond. No.                     1.06e+16
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 4.24e-21. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# """

# %%
intercept = np.ones((inputs.shape[0],1))
inputs = np.delete(inputs,15,axis=1) #12,8
inputs = np.hstack([intercept,inputs])


model = sm.OLS(outputs,inputs).fit()

model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.581
# Model:                            OLS   Adj. R-squared:                  0.581
# Method:                 Least Squares   F-statistic:                     3627.
# Date:                Thu, 05 May 2022   Prob (F-statistic):               0.00
# Time:                        20:22:59   Log-Likelihood:            -4.3109e+05
# No. Observations:               83709   AIC:                         8.622e+05
# Df Residuals:                   83676   BIC:                         8.626e+05
# Df Model:                          32
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          8.8557      0.736     12.040      0.000       7.414      10.297
# x1             8.8557      0.736     12.040      0.000       7.414      10.297
# x2             8.8557      0.736     12.040      0.000       7.414      10.297
# x3             8.8557      0.736     12.040      0.000       7.414      10.297
# x4            -2.1702      0.645     -3.365      0.001      -3.434      -0.906
# x5             6.8002      0.450     15.100      0.000       5.917       7.683
# x6             0.6420      0.142      4.525      0.000       0.364       0.920
# x7            -1.1764      2.340     -0.503      0.615      -5.762       3.410
# x8            -2.7459      0.334     -8.219      0.000      -3.401      -2.091
# x9             0.9105      0.314      2.903      0.004       0.296       1.525
# x10           -0.0462      0.014     -3.339      0.001      -0.073      -0.019
# x11          -17.5820      0.285    -61.714      0.000     -18.140     -17.024
# x12            8.3351      0.185     45.076      0.000       7.973       8.698
# x13           13.2740      0.430     30.873      0.000      12.431      14.117
# x14           13.1808      0.333     39.586      0.000      12.528      13.833
# x15           -0.0032      0.304     -0.010      0.992      -0.599       0.593
# x16           -0.9273      0.121     -7.635      0.000      -1.165      -0.689
# x17            0.0021      0.000      7.107      0.000       0.001       0.003
# x18           -1.4905      0.096    -15.529      0.000      -1.679      -1.302
# x19            0.6981      0.065     10.802      0.000       0.571       0.825
# x20           -0.0852      0.031     -2.767      0.006      -0.145      -0.025
# x21            0.0324      0.002     19.456      0.000       0.029       0.036
# x22           -0.4072      0.020    -20.828      0.000      -0.445      -0.369
# x23           -0.7291      0.062    -11.764      0.000      -0.851      -0.608
# x24            4.4504      0.315     14.130      0.000       3.833       5.068
# x25            0.3293      0.074      4.476      0.000       0.185       0.474
# x26           -5.1276      2.009     -2.552      0.011      -9.065      -1.190
# x27            4.2769      1.591      2.688      0.007       1.158       7.396
# x28            2.1067      0.170     12.365      0.000       1.773       2.441
# x29            1.0084      0.256      3.934      0.000       0.506       1.511
# x30           -4.8326      0.302    -15.978      0.000      -5.425      -4.240
# x31            0.0012      0.000      5.915      0.000       0.001       0.002
# x32            0.0176      0.002      8.093      0.000       0.013       0.022
# x33           -0.0357      0.006     -5.651      0.000      -0.048      -0.023
# x34            0.0451      0.002     29.777      0.000       0.042       0.048
# x35            0.2659      0.008     33.637      0.000       0.250       0.281
# ==============================================================================
# Omnibus:                    12419.731   Durbin-Watson:                   1.806
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            26555.524
# Skew:                           0.893   Prob(JB):                         0.00
# Kurtosis:                       5.103   Cond. No.                     1.06e+16
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 4.24e-21. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# """

# %%
intercept = np.ones((inputs.shape[0],1))
inputs = np.delete(inputs,[13,14,15,16],axis=1) #12,8
inputs = np.hstack([intercept,inputs])


model = sm.OLS(outputs,inputs).fit()

model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.503
# Model:                            OLS   Adj. R-squared:                  0.503
# Method:                 Least Squares   F-statistic:                     3262.
# Date:                Thu, 05 May 2022   Prob (F-statistic):               0.00
# Time:                        20:26:19   Log-Likelihood:            -4.3822e+05
# No. Observations:               83709   AIC:                         8.765e+05
# Df Residuals:                   83682   BIC:                         8.767e+05
# Df Model:                          26
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          4.8232      0.447     10.780      0.000       3.946       5.700
# x1             4.8232      0.447     10.780      0.000       3.946       5.700
# x2             4.8232      0.447     10.780      0.000       3.946       5.700
# x3             4.8232      0.447     10.780      0.000       3.946       5.700
# x4             4.8232      0.447     10.780      0.000       3.946       5.700
# x5             4.8232      0.447     10.780      0.000       3.946       5.700
# x6             4.8232      0.447     10.780      0.000       3.946       5.700
# x7            -2.9682      0.702     -4.227      0.000      -4.344      -1.592
# x8             6.7898      0.490     13.860      0.000       5.830       7.750
# x9             0.2678      0.154      1.734      0.083      -0.035       0.570
# x10           -0.3014      2.548     -0.118      0.906      -5.294       4.692
# x11           -2.1166      0.363     -5.825      0.000      -2.829      -1.404
# x12            1.3095      0.341      3.836      0.000       0.641       1.979
# x13            0.0894      0.015      6.079      0.000       0.061       0.118
# x14           23.7890      0.220    107.991      0.000      23.357      24.221
# x15           -1.7653      0.104    -16.898      0.000      -1.970      -1.561
# x16            0.8404      0.070     11.946      0.000       0.703       0.978
# x17           -0.1572      0.034     -4.693      0.000      -0.223      -0.092
# x18            0.0327      0.002     18.074      0.000       0.029       0.036
# x19           -0.4448      0.021    -20.980      0.000      -0.486      -0.403
# x20           -0.7674      0.067    -11.406      0.000      -0.899      -0.635
# x21            3.8194      0.342     11.176      0.000       3.150       4.489
# x22            1.0164      0.080     12.785      0.000       0.861       1.172
# x23           -2.0539      2.186     -0.939      0.348      -6.339       2.231
# x24           -2.0014      1.731     -1.156      0.248      -5.395       1.392
# x25            1.3913      0.185      7.536      0.000       1.029       1.753
# x26            9.3215      0.255     36.511      0.000       8.821       9.822
# x27          -15.4845      0.286    -54.214      0.000     -16.044     -14.925
# x28            0.0005      0.000      2.044      0.041     1.9e-05       0.001
# x29            0.0179      0.002      7.555      0.000       0.013       0.023
# x30           -0.0383      0.007     -5.568      0.000      -0.052      -0.025
# x31            0.0575      0.002     35.065      0.000       0.054       0.061
# x32            0.5034      0.008     60.831      0.000       0.487       0.520
# ==============================================================================
# Omnibus:                     9714.871   Durbin-Watson:                   1.818
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            16114.532
# Skew:                           0.812   Prob(JB):                         0.00
# Kurtosis:                       4.407   Cond. No.                     1.07e+16
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 3.81e-21. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# """

# %%
intercept = np.ones((inputs.shape[0],1))
#inputs = np.delete(inputs,17,axis=1) #12,8

inputs = np.hstack([intercept,inputs])
inputs = np.delete(inputs,17,axis=1) #12,8

model = sm.OLS(outputs,inputs).fit()

model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.502
# Model:                            OLS   Adj. R-squared:                  0.502
# Method:                 Least Squares   F-statistic:                     3381.
# Date:                Thu, 05 May 2022   Prob (F-statistic):               0.00
# Time:                        20:28:28   Log-Likelihood:            -4.3829e+05
# No. Observations:               83709   AIC:                         8.766e+05
# Df Residuals:                   83683   BIC:                         8.769e+05
# Df Model:                          25
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          4.2345      0.392     10.807      0.000       3.467       5.003
# x1             4.2345      0.392     10.807      0.000       3.467       5.003
# x2             4.2345      0.392     10.807      0.000       3.467       5.003
# x3             4.2345      0.392     10.807      0.000       3.467       5.003
# x4             4.2345      0.392     10.807      0.000       3.467       5.003
# x5             4.2345      0.392     10.807      0.000       3.467       5.003
# x6             4.2345      0.392     10.807      0.000       3.467       5.003
# x7             4.2345      0.392     10.807      0.000       3.467       5.003
# x8            -3.0203      0.703     -4.298      0.000      -4.398      -1.643
# x9             6.7155      0.490     13.698      0.000       5.755       7.676
# x10            0.2941      0.155      1.903      0.057      -0.009       0.597
# x11           -0.4471      2.550     -0.175      0.861      -5.444       4.550
# x12           -2.1105      0.364     -5.803      0.000      -2.823      -1.398
# x13            1.3051      0.342      3.820      0.000       0.635       1.975
# x14            0.0893      0.015      6.067      0.000       0.060       0.118
# x15           23.8260      0.220    108.079      0.000      23.394      24.258
# x16           -0.9070      0.076    -11.949      0.000      -1.056      -0.758
# x17            0.2057      0.014     14.537      0.000       0.178       0.233
# x18            0.0298      0.002     16.606      0.000       0.026       0.033
# x19           -0.4492      0.021    -21.175      0.000      -0.491      -0.408
# x20           -0.7800      0.067    -11.586      0.000      -0.912      -0.648
# x21            3.8582      0.342     11.281      0.000       3.188       4.529
# x22            1.0195      0.080     12.812      0.000       0.863       1.175
# x23           -1.9175      2.188     -0.876      0.381      -6.206       2.371
# x24           -2.1488      1.733     -1.240      0.215      -5.545       1.247
# x25            1.3943      0.185      7.546      0.000       1.032       1.756
# x26            9.3376      0.256     36.544      0.000       8.837       9.838
# x27          -15.5411      0.286    -54.373      0.000     -16.101     -14.981
# x28            0.0004      0.000      1.859      0.063    -2.3e-05       0.001
# x29            0.0184      0.002      7.744      0.000       0.014       0.023
# x30           -0.0393      0.007     -5.710      0.000      -0.053      -0.026
# x31            0.0575      0.002     35.046      0.000       0.054       0.061
# x32            0.5055      0.008     61.047      0.000       0.489       0.522
# ==============================================================================
# Omnibus:                     9731.558   Durbin-Watson:                   1.817
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            16147.137
# Skew:                           0.813   Prob(JB):                         0.00
# Kurtosis:                       4.408   Cond. No.                     1.07e+16
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 3.81e-21. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# """

# %%
intercept = np.ones((inputs.shape[0],1))
#inputs = np.delete(inputs,17,axis=1) #12,8

inputs = np.hstack([intercept,inputs])
inputs = np.delete(inputs,12,axis=1) #12,8

model = sm.OLS(outputs,inputs).fit()

model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.502
# Model:                            OLS   Adj. R-squared:                  0.502
# Method:                 Least Squares   F-statistic:                     3522.
# Date:                Thu, 05 May 2022   Prob (F-statistic):               0.00
# Time:                        20:29:00   Log-Likelihood:            -4.3829e+05
# No. Observations:               83709   AIC:                         8.766e+05
# Df Residuals:                   83684   BIC:                         8.769e+05
# Df Model:                          24
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          3.7143      0.202     18.398      0.000       3.319       4.110
# x1             3.7143      0.202     18.398      0.000       3.319       4.110
# x2             3.7143      0.202     18.398      0.000       3.319       4.110
# x3             3.7143      0.202     18.398      0.000       3.319       4.110
# x4             3.7143      0.202     18.398      0.000       3.319       4.110
# x5             3.7143      0.202     18.398      0.000       3.319       4.110
# x6             3.7143      0.202     18.398      0.000       3.319       4.110
# x7             3.7143      0.202     18.398      0.000       3.319       4.110
# x8             3.7143      0.202     18.398      0.000       3.319       4.110
# x9            -3.0205      0.703     -4.298      0.000      -4.398      -1.643
# x10            6.7152      0.490     13.698      0.000       5.754       7.676
# x11            0.2943      0.155      1.905      0.057      -0.009       0.597
# x12           -2.1122      0.364     -5.810      0.000      -2.825      -1.400
# x13            1.3053      0.342      3.821      0.000       0.636       1.975
# x14            0.0893      0.015      6.067      0.000       0.060       0.118
# x15           23.8263      0.220    108.083      0.000      23.394      24.258
# x16           -0.9069      0.076    -11.948      0.000      -1.056      -0.758
# x17            0.2056      0.014     14.536      0.000       0.178       0.233
# x18            0.0298      0.002     16.608      0.000       0.026       0.033
# x19           -0.4493      0.021    -21.179      0.000      -0.491      -0.408
# x20           -0.7800      0.067    -11.586      0.000      -0.912      -0.648
# x21            3.8586      0.342     11.282      0.000       3.188       4.529
# x22            1.0194      0.080     12.811      0.000       0.863       1.175
# x23           -1.9178      2.188     -0.876      0.381      -6.207       2.371
# x24           -2.1482      1.733     -1.240      0.215      -5.544       1.248
# x25            1.3942      0.185      7.545      0.000       1.032       1.756
# x26            9.3367      0.255     36.548      0.000       8.836       9.837
# x27          -15.5415      0.286    -54.377      0.000     -16.102     -14.981
# x28            0.0004      0.000      1.864      0.062   -2.17e-05       0.001
# x29            0.0184      0.002      7.745      0.000       0.014       0.023
# x30           -0.0393      0.007     -5.709      0.000      -0.053      -0.026
# x31            0.0575      0.002     35.049      0.000       0.054       0.061
# x32            0.5055      0.008     61.052      0.000       0.489       0.522
# ==============================================================================
# Omnibus:                     9731.438   Durbin-Watson:                   1.817
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            16146.524
# Skew:                           0.813   Prob(JB):                         0.00
# Kurtosis:                       4.408   Cond. No.                     1.21e+16
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 2.97e-21. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# """

# %%
df.head()
# Out:
#    price_x  experiences_offered  host_is_superhost  host_listings_count  \
# 0     88.0                    1                  0                  3.0
# 1     65.0                    0                  0                  4.0
# 2    100.0                    3                  0                  1.0
# 3    225.0                    2                  0                  7.0
# 4    150.0                    0                  0                  3.0
#
#    host_has_profile_pic  host_identity_verified  is_location_exact  \
# 0                     1                       1                  1
# 1                     1                       1                  1
# 2                     1                       1                  1
# 3                     1                       1                  0
# 4                     1                       0                  1
#
#    property_type  room_type_y  accommodates  bathrooms  bedrooms  beds  \
# 0              1            0           4.0        1.0       1.0   3.0
# 1              1            2           2.0        1.0       1.0   0.0
# 2              1            0           2.0        1.0       1.0   1.0
# 3              1            0           6.0        2.0       3.0   3.0
# 4              3            2           2.0        1.0       1.0   1.0
#
#    bed_type  guests_included  extra_people  minimum_nights_y  maximum_nights  \
# 0         4              2.0          20.0               2.0           180.0
# 1         4              1.0          15.0               1.0            29.0
# 2         4              2.0           0.0               4.0            50.0
# 3         4              3.0          10.0               3.0           365.0
# 4         4              1.0           0.0               3.0            21.0
#
#    availability_30  availability_60  availability_90  availability_365_y  \
# 0             12.0               42               72                 347
# 1             12.0               42               72                 347
# 2              0.0                0               13                 288
# 3              9.0               39               69                 326
# 4             11.0               41               71                 346
#
#    number_of_reviews_y  number_of_reviews_ltm  instant_bookable  \
# 0                 22.0                    9.0                 1
# 1                 21.0                    5.0                 0
# 2                 22.0                    4.0                 1
# 3                 42.0                    2.0                 1
# 4                  0.0                    0.0                 0
#
#    cancellation_policy  require_guest_profile_picture  \
# 0                    5                              0
# 1                    3                              0
# 2                    5                              1
# 3                    5                              0
# 4                    5                              0
#
#    require_guest_phone_verification  calculated_host_listings_count_y  \
# 0                                 1                               2.0
# 1                                 0                               3.0
# 2                                 1                               1.0
# 3                                 0                               7.0
# 4                                 0                               2.0
#
#    calculated_host_listings_count_entire_homes  \
# 0                                          2.0
# 1                                          1.0
# 2                                          1.0
# 3                                          3.0
# 4                                          0.0
#
#    calculated_host_listings_count_private_rooms  host_since  street  city  \
# 0                                           0.0          36     853   355
# 1                                           2.0          44     481   306
# 2                                           0.0          50     853   355
# 3                                           0.0          57     720   355
# 4                                           2.0          58     853   355
#
#    security_deposit  cleaning_fee
# 0             350.0          35.0
# 1             100.0          15.0
# 2             150.0          50.0
# 3             350.0          90.0
# 4             100.0          30.0
