# %% [markdown]
# #### https://www.kaggle.com/datasets/imoore/age-dataset
#
# Download dataset from above link, you will predict at what age person will die (Age of Death)

# %% [markdown]
# # Regression Assignment (End-to-End)

# %%
#import libraries
import pandas as pd, numpy as np, matplotlib.pyplot as plt,seaborn as sns,warnings,sklearn
warnings.filterwarnings('ignore')
pd.options.display.max_rows=100

# %%
#Data understanding
df=pd.read_csv(r"A:\datasets\AgeDataset-V1.csv")
df.head(100)
# Out:
#        Id                                         Name  \
# 0     Q23                            George Washington
# 1     Q42                                Douglas Adams
# 2     Q91                              Abraham Lincoln
# 3    Q254                      Wolfgang Amadeus Mozart
# 4    Q255                         Ludwig van Beethoven
# 5    Q260                    Jean-François Champollion
# 6    Q272                                  Paul Morand
# 7    Q296                                 Claude Monet
# 8    Q297                              Diego Velázquez
# 9    Q301                                     El Greco
# 10   Q303                                Elvis Presley
# 11   Q307                              Galileo Galilei
# 12   Q335                              Patricio Aylwin
# 13   Q346                           Louis IX of France
# 14   Q352                                 Adolf Hitler
# 15   Q353                           Blanche of Castile
# 16   Q354                                   Piet Kraak
# 17   Q368                             Augusto Pinochet
# 18   Q377                                 Yanka Kupala
# 19   Q379                           František Plánička
# 20   Q407                               Linda Lovelace
# 21   Q409                                   Bob Marley
# 22   Q410                                   Carl Sagan
# 23   Q440                             Salvador Allende
# 24   Q448                                Denis Diderot
# 25   Q449                             Georges Brassens
# 26   Q464                    Philipp Ludwig von Seidel
# 27   Q475                        Eduardo Frei Montalva
# 28   Q493                               Arthur Rimbaud
# 29   Q498  Ulrich Frédéric Woldemar, Comte de Lowendal
# 30   Q501                           Charles Baudelaire
# 31   Q502                                     Stendhal
# 32   Q504                                   Émile Zola
# 33   Q512                            Vladimir Vysotsky
# 34   Q517                                     Napoleon
# 35   Q529                                Louis Pasteur
# 36   Q535                                  Victor Hugo
# 37   Q539                           Giuseppe Garibaldi
# 38   Q559                             Claude Bourgelat
# 39   Q562                                Pierre Poivre
# 40   Q576                             Jorge Alessandri
# 41   Q579                      Carlos Ibáñez del Campo
# 42   Q590                               Luís de Camões
# 43   Q619                          Nicolaus Copernicus
# 44   Q632                                  Jean Moulin
# 45   Q635                                    Cleopatra
# 46   Q651                    Friedrich Theodor Vischer
# 47   Q675                           André-Marie Ampère
# 48   Q680                             Alessandro Volta
# 49   Q687                                      Molière
# 50   Q692                          William Shakespeare
# 51   Q720                                 Genghis Khan
# 52   Q742                                  Jean Racine
# 53   Q747                             Pierre Corneille
# 54   Q755                                Paul Verlaine
# 55   Q762                            Leonardo da Vinci
# 56   Q765                                     Dario Fo
# 57   Q767                            Stéphane Mallarmé
# 58   Q815                      Gabriel Gonzáles Videla
# 59   Q820                            Juan Antonio Rios
# 60   Q835                             Mikhail Bulgakov
# 61   Q838                                Andrei Rublev
# 62   Q845                          Pedro Aguirre Cerda
# 63   Q848                            Arturo Alessandri
# 64   Q849                              François Villon
# 65   Q853                             Andrei Tarkovsky
# 66   Q855                                Joseph Stalin
# 67   Q857                         Juan Luis Sanfuentes
# 68   Q859                                        Plato
# 69   Q862                               Joseph Brodsky
# 70   Q868                                    Aristotle
# 71   Q882                              Charlie Chaplin
# 72   Q885                              Józef Piłsudski
# 43                           Researcher        1473      1543.0
# 44  Official; french resistance fighter        1899      1943.0
# 45                            Sovereign         -69       -30.0
# 46                           Researcher        1807      1887.0
# 47                           Researcher        1775      1836.0
# 48                           Researcher        1745      1827.0
# 49                               Artist        1622      1673.0
# 50                           Playwright        1564      1616.0
# 51                   Military personnel        1162      1227.0
# 52                           Researcher        1639      1699.0
# 53                               Artist        1606      1684.0
# 54                               Artist        1844      1896.0
# 55                           Researcher        1452      1519.0
# 56                               Artist        1926      2016.0
# 57                               Artist        1842      1898.0
# 58                           Politician        1898      1980.0
# 59                           Politician        1888      1946.0
# 60                               Artist        1891      1940.0
# 61                               Artist        1360      1428.0
# 62                           Politician        1879      1941.0
# 63                           Politician        1868      1950.0
# 64                               Artist        1431      1463.0
# 65                               Artist        1932      1986.0
# 66                           Politician        1879      1953.0
# 67                           Politician        1858      1930.0
# 68                               Artist        -427      -347.0
# 69                               Artist        1940      1996.0
# 70                          Philosopher        -384      -322.0
# 71                               Artist        1889      1977.0
# 72                           Politician        1867      1935.0
# 73                           Researcher        1892      1973.0
# 74                               Artist        1883      1924.0
# 75                           Researcher        1899      1986.0
# 76                          Philosopher        -470      -399.0
# 77                               Artist        1937      2012.0
# 78                           Researcher        1872      1928.0
# 79                               Artist        1927      2010.0
# 80                               Artist        1890      1974.0
# 81                           Researcher        1642      1727.0
# 82                           Researcher        1879      1955.0
# 83                               Artist        1798      1834.0
# 84                           Researcher        1908      1991.0
# 85                               Artist        1879      1954.0
# 86                           Researcher        1920      2005.0
# 87                               Artist        1821      1881.0
# 88                           Researcher        1921      1989.0
# 89                               Artist        1869      1948.0
# 90                               Artist        1800      1849.0
# 91                           Researcher        1809      1882.0
# 92                           Researcher        1707      1778.0
# 93                           Researcher        1868      1947.0
# 94                           Politician        1896      1940.0
# 95                               Artist        1785      1873.0
# 96                               Artist        1265      1321.0
# 97                               Artist        1683      1764.0
# 98                           Politician        1917      1984.0
# 99                               Artist        1803      1869.0
#
#        Manner of death  Age of death
# 0       natural causes          67.0
# 1       natural causes          49.0
# 2             homicide          56.0
# 3                  NaN          35.0
# 4                  NaN          57.0
# 5       natural causes          42.0
# 6                  NaN          88.0
# 7       natural causes          86.0
# 8                  NaN          61.0
# 9                  NaN          73.0
# 10      natural causes          42.0
# 11                 NaN          78.0
# 12                 NaN          98.0
# 13      natural causes          56.0
# 14             suicide          56.0
# 15                 NaN          64.0
# 16                 NaN          63.0
# 17      natural causes          91.0
# 18                 NaN          60.0
# 19                 NaN          92.0
# 20            accident          53.0
# 21      natural causes          36.0
# 22      natural causes          62.0
# 23             suicide          65.0
# 24                 NaN          71.0
# 25      natural causes          60.0
# 26                 NaN          75.0
# 27            homicide          71.0
# 28      natural causes          37.0
# 29                 NaN          55.0
# 30      natural causes          46.0
# 31      natural causes          59.0
# 32            accident          62.0
# 33      natural causes          42.0
# 34      natural causes          52.0
# 35      natural causes          73.0
# 36                 NaN          83.0
# 37      natural causes          75.0
# 38                 NaN          67.0
# 39                 NaN          67.0
# 40                 NaN          90.0
# 41                 NaN          83.0
# 42                 NaN          56.0
# 43      natural causes          70.0
# 44            homicide          44.0
# 45             suicide          39.0
# 46                 NaN          80.0
# 47                 NaN          61.0
# 48                 NaN          82.0
# 49      natural causes          51.0
# 50                 NaN          52.0
# 51                 NaN          65.0
# 52      natural causes          60.0
# 53                 NaN          78.0
# 54      natural causes          52.0
# 55      natural causes          67.0
# 56                 NaN          90.0
# 57                 NaN          56.0
# 58                 NaN          82.0
# 59      natural causes          58.0
# 60      natural causes          49.0
# 61      natural causes          68.0
# 62      natural causes          62.0
# 63      natural causes          82.0
# 64                 NaN          32.0
# 65      natural causes          54.0
# 66      natural causes          74.0
# 67                 NaN          72.0
# 68                 NaN          80.0
# 69      natural causes          56.0
# 70      natural causes          62.0
# 71      natural causes          88.0
# 72      natural causes          68.0
# 73                 NaN          81.0
# 74      natural causes          41.0
# 75      natural causes          87.0
# 76  capital punishment          71.0
# 77                 NaN          75.0
# 78            accident          56.0
# 79      natural causes          83.0
# 80                 NaN          84.0
# 81                 NaN          85.0
# 82      natural causes          76.0
# 83      natural causes          36.0
# 84      natural causes          83.0
# 85                 NaN          75.0
# 86      natural causes          85.0
# 87                 NaN          60.0
# 88      natural causes          68.0
# 89            homicide          79.0
# 90      natural causes          49.0
# 91                 NaN          73.0
# 92                 NaN          71.0
# 93                 NaN          79.0
# 94            accident          44.0
# 95      natural causes          88.0
# 96                 NaN          56.0
# 97                 NaN          81.0
# 98            homicide          67.0
# 99                 NaN          66.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1223009 entries, 0 to 1223008
# Data columns (total 10 columns):
#  #   Column             Non-Null Count    Dtype
# ---  ------             --------------    -----
#  0   Id                 1223009 non-null  object
#  1   Name               1223009 non-null  object
#  2   Short description  1155109 non-null  object
#  3   Gender             1089363 non-null  object
#  4   Country            887500 non-null   object
#  5   Occupation         1016095 non-null  object
#  6   Birth year         1223009 non-null  int64
#  7   Death year         1223008 non-null  float64
#  8   Manner of death    53603 non-null    object
#  9   Age of death       1223008 non-null  float64
# dtypes: float64(2), int64(1), object(7)
# memory usage: 93.3+ MB

# %%
df.shape
# Out:
# (1223009, 10)

# %%
df.describe()
# Out:
#          Birth year    Death year  Age of death
# count  1.223009e+06  1.223008e+06  1.223008e+06
# mean   1.844972e+03  1.914246e+03  6.927406e+01
# std    1.479390e+02  1.516898e+02  1.662938e+01
# min   -2.700000e+03 -2.659000e+03  0.000000e+00
# 25%    1.828000e+03  1.895000e+03  6.000000e+01
# 50%    1.887000e+03  1.955000e+03  7.200000e+01
# 75%    1.918000e+03  1.994000e+03  8.100000e+01
# max    2.016000e+03  2.021000e+03  1.690000e+02

# %%
for i in df.columns:
    print(i,df[i].isnull().sum()/df.shape[0],'%')
# Out:
# Id 0.0 %
# Name 0.0 %
# Short description 0.05551880648466201 %
# Gender 0.10927638308467068 %
# Country 0.2743307694383279 %
# Occupation 0.1691843641379581 %
# Birth year 0.0 %
# Death year 8.176554710554051e-07 %
# Manner of death 0.9561712137850171 %
# Age of death 8.176554710554051e-07 %

# %%
df['Birth year'][df['Birth year']<1000].count()
# Out:
# 5697

# %% [markdown]
# ## Data Cleaning

# %%
print(df.shape)
df.drop('Id',inplace=True,axis=1)
print(df.shape)
# Out:
# (1223009, 10)
# (1223009, 9)

# %% [markdown]
# #### Inference: Id column is completely unique therefore it doesnot contribute anything to model

# %%
print(df.shape)
df.drop('Short description',inplace=True,axis=1)
print(df.shape)
# Out:
# (1223009, 9)
# (1223009, 8)

# %%
num_cols=df.select_dtypes(['int64','float64']).columns
cat_cols=df.select_dtypes('object').columns
num_cols,cat_cols
# Out:
# (Index(['Birth year', 'Death year', 'Age of death'], dtype='object'),
#  Index(['Name', 'Gender', 'Country', 'Occupation', 'Manner of death'], dtype='object'))

# %% [markdown]
# #### Inference: Short description column cannot be encoded further for model so its dropped

# %% [markdown]
# ### Checking Null Columns

# %%
num_null_cols=[]
cat_null_cols=[]
for i in num_cols:
    if df[i].isnull().sum()>0:
        num_null_cols.append(i)
for i in cat_cols:
    if df[i].isnull().sum()>0:
        cat_null_cols.append(i)
print(num_null_cols,cat_null_cols)
# Out:
# ['Death year', 'Age of death'] ['Gender', 'Country', 'Occupation', 'Manner of death']

# %% [markdown]
# ### Checking Outlier Columns

# %%
outlier_cols=[]
for i in num_cols:
    iqr=df[i].quantile(0.75)-df[i].quantile(0.25)
    lower_range=df[i].quantile(0.25)-(1.5*iqr)
    higher_range=df[i].quantile(0.75)+(1.5*iqr)
    if df[i][df[i]<lower_range].count()>0 or df[i][df[i]>higher_range].count()>0:
        print(df[i][df[i]<lower_range].count() + df[i][df[i]>higher_range].count(),i)
        outlier_cols.append(i)
outlier_cols
# Out:
# 104127 Birth year
# 99870 Death year
# 29353 Age of death
# ['Birth year', 'Death year', 'Age of death']

# %% [markdown]
# #### Inference: Since no. of outliers are more and for this data outlier imputaion will affect the data for model so decided not to perform outlier imputaion

# %% [markdown]
# ### Numerical Null Imputation

# %%
for i in num_null_cols:
    if i in outlier_cols:
        df[i]=df[i].fillna(df[i].median())
    else:
        df[i]=df[i].fillna(df[i].mean())
for i in num_null_cols:
    if df[i].isnull().sum()>0:
        print(True)
    else:
        print(False)
# Out:
# False
# False

# %% [markdown]
# ### Categorical Null Imputation

# %%
for i in cat_null_cols:
    df[i]=df[i].fillna(df[i].mode()[0])
for i in cat_null_cols:
    if df[i].isnull().sum()>0:
        print(True)
    else:
        print(False)
# Out:
# False
# False
# False
# False

# %% [markdown]
# # EDA

# %% [markdown]
# ### Univarite Analysis

# %%
df.columns
# Out:
# Index(['Name', 'Gender', 'Country', 'Occupation', 'Birth year', 'Death year',
#        'Manner of death', 'Age of death'],
#       dtype='object')

# %%
plt.figure(figsize=(10,5))
df['Age of death'].value_counts().nlargest(50).plot.bar()
plt.xlabel('Age')
plt.ylabel('No. of Deaths')
plt.title('Age of top 50 most deaths')
plt.show()

# %% [markdown]
# #### Inference: By the above graph we can see that most of the deaths take place between the age group of 70-84 as per the top 15 death counts

# %%
plt.figure(figsize=(10,5))
df['Age of death'].value_counts().nsmallest(50).plot.bar()
plt.xlabel('Age')
plt.ylabel('No. of Deaths')
plt.title('Age of top 50 most deaths')
plt.show()

# %% [markdown]
# #### Inference:

# %%
#bivarite

# %%
#derived metrics

# %%
#visulization (if any extra)

# %% [markdown]
# # Feature Engineering

# %%
#VIF and Feature selection methods

# %%
#Data splitting

# %% [markdown]
# # Model building

# %%
'''
Linear regression
Lasso regression
Ridge regression
SVR regression
Polynomial regression
'''
# Out:
# '\nLinear regression\nLasso regression\nRidge regression\nSVR regression\nPolynomial regression\n'

# %% [markdown]
# # Metrics

# %%
#create a Data Frame showing metrics of above models

# %%
# explain which model does it better

# %% [markdown]
# # GridSearch CV

# %%
# implement grid search for the best model, recommend best hyperparameters
