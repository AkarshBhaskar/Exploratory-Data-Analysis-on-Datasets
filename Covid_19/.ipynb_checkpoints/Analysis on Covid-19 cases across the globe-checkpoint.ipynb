# %% [markdown]
# # Assignment Data Visualization, EDA and Statistics

# %% [markdown]
# ### Exploratory data analysis on COVID-19 across the globe.
#
# Problem is divided into 3 sections.
# - Data Understaing,
# - EDA and Visualization
# - Statistics.

# %% [markdown]
# Name:Akarsh B A
#
# Email:akarsh.bhaskaranil@gmail.com

# %% [markdown]
# Please pledge for honour code.
#
#
#  <b> I, Akarsh B A, promise that during the course of this assignment I shall not use unethical and nefarious means in an attempt to defraud the sanctity of the assignment and gain an unfair advantage. I will adhere to the virtues of truth and honesty. I will honour the SURE Trust honour code. </b>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import math
from geopy.geocoders import Nominatim
pd.options.display.max_rows=100

# %%
df = pd.read_csv(r"A:\datasets\covid_19.csv")

# %% [markdown]
# ## Data Understanding

# %%
#1 properties of data. shape, columns

# %%
df.shape
# Out:
# (49068, 10)

# %%
df.columns
# Out:
# Index(['Province/State', 'Country/Region', 'Lat', 'Long', 'Date', 'Confirmed',
#        'Deaths', 'Recovered', 'Active', 'WHO Region'],
#       dtype='object')

# %%
#2 data glipse with info and describe

# %%
df.head(100)
# Out:
#                   Province/State            Country/Region        Lat  \
# 0                            NaN               Afghanistan  33.939110
# 1                            NaN                   Albania  41.153300
# 2                            NaN                   Algeria  28.033900
# 3                            NaN                   Andorra  42.506300
# 4                            NaN                    Angola -11.202700
# 5                            NaN       Antigua and Barbuda  17.060800
# 6                            NaN                 Argentina -38.416100
# 7                            NaN                   Armenia  40.069100
# 8   Australian Capital Territory                 Australia -35.473500
# 9                New South Wales                 Australia -33.868800
# 10            Northern Territory                 Australia -12.463400
# 11                    Queensland                 Australia -27.469800
# 12               South Australia                 Australia -34.928500
# 13                      Tasmania                 Australia -42.882100
# 14                      Victoria                 Australia -37.813600
# 15             Western Australia                 Australia -31.950500
# 16                           NaN                   Austria  47.516200
# 17                           NaN                Azerbaijan  40.143100
# 18                           NaN                   Bahamas  25.025885
# 19                           NaN                   Bahrain  26.027500
# 20                           NaN                Bangladesh  23.685000
# 21                           NaN                  Barbados  13.193900
# 22                           NaN                   Belarus  53.709800
# 23                           NaN                   Belgium  50.833300
# 24                           NaN                     Benin   9.307700
# 25                           NaN                    Bhutan  27.514200
# 26                           NaN                   Bolivia -16.290200
# 27                           NaN    Bosnia and Herzegovina  43.915900
# 28                           NaN                    Brazil -14.235000
# 29                           NaN                    Brunei   4.535300
# 30                           NaN                  Bulgaria  42.733900
# 31                           NaN              Burkina Faso  12.238300
# 32                           NaN                Cabo Verde  16.538800
# 33                           NaN                  Cambodia  11.550000
# 34                           NaN                  Cameroon   3.848000
# 35                       Alberta                    Canada  53.933300
# 36              British Columbia                    Canada  53.726700
# 37                      Manitoba                    Canada  53.760900
# 38                 New Brunswick                    Canada  46.565300
# 39     Newfoundland and Labrador                    Canada  53.135500
# 40                   Nova Scotia                    Canada  44.682000
# 41                       Ontario                    Canada  51.253800
# 42          Prince Edward Island                    Canada  46.510700
# 43                        Quebec                    Canada  52.939900
# 44                  Saskatchewan                    Canada  52.939900
# 45                           NaN  Central African Republic   6.611100
# 46                           NaN                      Chad  15.454200
# 47                           NaN                     Chile -35.675100
# 48                         Anhui                     China  31.825700
# 49                       Beijing                     China  40.182400
# 50                     Chongqing                     China  30.057200
# 51                        Fujian                     China  26.078900
# 52                         Gansu                     China  35.751800
# 53                     Guangdong                     China  23.341700
# 54                       Guangxi                     China  23.829800
# 55                       Guizhou                     China  26.815400
# 56                        Hainan                     China  19.195900
# 57                         Hebei                     China  39.549000
# 58                  Heilongjiang                     China  47.862000
# 59                         Henan                     China  37.895700
# 60                     Hong Kong                     China  22.300000
# 61                         Hubei                     China  30.975600
# 62                         Hunan                     China  27.610400
# 63                Inner Mongolia                     China  44.093500
# 64                       Jiangsu                     China  32.971100
# 65                       Jiangxi                     China  27.614000
# 66                         Jilin                     China  43.666100
# 67                      Liaoning                     China  41.295600
# 68                         Macau                     China  22.166700
# 69                       Ningxia                     China  37.269200
# 70                       Qinghai                     China  35.745200
# 71                       Shaanxi                     China  35.191700
# 72                      Shandong                     China  36.342700
# 73                      Shanghai                     China  31.202000
# 74                        Shanxi                     China  37.577700
# 75                       Sichuan                     China  30.617100
# 76                       Tianjin                     China  39.305400
# 77                         Tibet                     China  31.692700
# 78                      Xinjiang                     China  41.112900
# 79                        Yunnan                     China  24.974000
# 80                      Zhejiang                     China  29.183200
# 81                           NaN                  Colombia   4.570900
# 82                           NaN       Congo (Brazzaville)  -0.228000
# 83                           NaN          Congo (Kinshasa)  -4.038300
# 84                           NaN                Costa Rica   9.748900
# 85                           NaN             Cote d'Ivoire   7.540000
# 86                           NaN                   Croatia  45.100000
# 87                           NaN                      Cuba  21.521757
# 88                           NaN                    Cyprus  35.126400
# 89                           NaN                   Czechia  49.817500
# 90                 Faroe Islands                   Denmark  61.892600
# 91                     Greenland                 Greenland  71.706900
# 92                           NaN                   Denmark  56.263900
# 93                           NaN                  Djibouti  11.825100
# 94                           NaN        Dominican Republic  18.735700
# 95                           NaN                   Ecuador  -1.831200
# 96                           NaN                     Egypt  26.820553
# 97                           NaN               El Salvador  13.794200
# 98                           NaN         Equatorial Guinea   1.650800
# 99                           NaN                   Eritrea  15.179400
#
#           Long        Date  Confirmed  Deaths  Recovered  Active  \
# 0    67.709953  2020-01-22          0       0          0       0
# 1    20.168300  2020-01-22          0       0          0       0
# 2     1.659600  2020-01-22          0       0          0       0
# 3     1.521800  2020-01-22          0       0          0       0
# 4    17.873900  2020-01-22          0       0          0       0
# 5   -61.796400  2020-01-22          0       0          0       0
# 6   -63.616700  2020-01-22          0       0          0       0
# 7    45.038200  2020-01-22          0       0          0       0
# 8   149.012400  2020-01-22          0       0          0       0
# 9   151.209300  2020-01-22          0       0          0       0
# 10  130.845600  2020-01-22          0       0          0       0
# 11  153.025100  2020-01-22          0       0          0       0
# 12  138.600700  2020-01-22          0       0          0       0
# 13  147.327200  2020-01-22          0       0          0       0
# 14  144.963100  2020-01-22          0       0          0       0
# 15  115.860500  2020-01-22          0       0          0       0
# 16   14.550100  2020-01-22          0       0          0       0
# 17   47.576900  2020-01-22          0       0          0       0
# 18  -78.035889  2020-01-22          0       0          0       0
# 19   50.550000  2020-01-22          0       0          0       0
# 20   90.356300  2020-01-22          0       0          0       0
# 21  -59.543200  2020-01-22          0       0          0       0
# 22   27.953400  2020-01-22          0       0          0       0
# 23    4.469936  2020-01-22          0       0          0       0
# 24    2.315800  2020-01-22          0       0          0       0
# 25   90.433600  2020-01-22          0       0          0       0
# 26  -63.588700  2020-01-22          0       0          0       0
# 27   17.679100  2020-01-22          0       0          0       0
# 28  -51.925300  2020-01-22          0       0          0       0
# 29  114.727700  2020-01-22          0       0          0       0
# 30   25.485800  2020-01-22          0       0          0       0
# 31   -1.561600  2020-01-22          0       0          0       0
# 32  -23.041800  2020-01-22          0       0          0       0
# 33  104.916700  2020-01-22          0       0          0       0
# 34   11.502100  2020-01-22          0       0          0       0
# 35 -116.576500  2020-01-22          0       0          0       0
# 36 -127.647600  2020-01-22          0       0          0       0
# 37  -98.813900  2020-01-22          0       0          0       0
# 38  -66.461900  2020-01-22          0       0          0       0
# 39  -57.660400  2020-01-22          0       0          0       0
# 40  -63.744300  2020-01-22          0       0          0       0
# 41  -85.323200  2020-01-22          0       0          0       0
# 42  -63.416800  2020-01-22          0       0          0       0
# 43  -73.549100  2020-01-22          0       0          0       0
# 44 -106.450900  2020-01-22          0       0          0       0
# 45   20.939400  2020-01-22          0       0          0       0
# 46   18.732200  2020-01-22          0       0          0       0
# 47  -71.543000  2020-01-22          0       0          0       0
# 48  117.226400  2020-01-22          1       0          0       1
# 49  116.414200  2020-01-22         14       0          0      14
# 50  107.874000  2020-01-22          6       0          0       6
# 51  117.987400  2020-01-22          1       0          0       1
# 52  104.286100  2020-01-22          0       0          0       0
# 53  113.424400  2020-01-22         26       0          0      26
# 54  108.788100  2020-01-22          2       0          0       2
# 55  106.874800  2020-01-22          1       0          0       1
# 56  109.745300  2020-01-22          4       0          0       4
# 57  116.130600  2020-01-22          1       0          0       1
# 58  127.761500  2020-01-22          0       0          0       0
# 59  114.904200  2020-01-22          5       0          0       5
# 60  114.200000  2020-01-22          0       0          0       0
# 61  112.270700  2020-01-22        444      17         28     399
# 62  111.708800  2020-01-22          4       0          0       4
# 63  113.944800  2020-01-22          0       0          0       0
# 64  119.455000  2020-01-22          1       0          0       1
# 65  115.722100  2020-01-22          2       0          0       2
# 66  126.192300  2020-01-22          0       0          0       0
# 67  122.608500  2020-01-22          2       0          0       2
# 68  113.550000  2020-01-22          1       0          0       1
# 69  106.165500  2020-01-22          1       0          0       1
# 70   95.995600  2020-01-22          0       0          0       0
# 71  108.870100  2020-01-22          0       0          0       0
# 72  118.149800  2020-01-22          2       0          0       2
# 73  121.449100  2020-01-22          9       0          0       9
# 74  112.292200  2020-01-22          1       0          0       1
# 75  102.710300  2020-01-22          5       0          0       5
# 76  117.323000  2020-01-22          4       0          0       4
# 77   88.092400  2020-01-22          0       0          0       0
# 78   85.240100  2020-01-22          0       0          0       0
# 79  101.487000  2020-01-22          1       0          0       1
# 80  120.093400  2020-01-22         10       0          0      10
# 81  -74.297300  2020-01-22          0       0          0       0
# 82   15.827700  2020-01-22          0       0          0       0
# 83   21.758700  2020-01-22          0       0          0       0
# 84  -83.753400  2020-01-22          0       0          0       0
# 85   -5.547100  2020-01-22          0       0          0       0
# 86   15.200000  2020-01-22          0       0          0       0
# 87  -77.781167  2020-01-22          0       0          0       0
# 88   33.429900  2020-01-22          0       0          0       0
# 89   15.473000  2020-01-22          0       0          0       0
# 90   -6.911800  2020-01-22          0       0          0       0
# 91  -42.604300  2020-01-22          0       0          0       0
# 92    9.501800  2020-01-22          0       0          0       0
# 93   42.590300  2020-01-22          0       0          0       0
# 94  -70.162700  2020-01-22          0       0          0       0
# 95  -78.183400  2020-01-22          0       0          0       0
# 96   30.802498  2020-01-22          0       0          0       0
# 97  -88.896500  2020-01-22          0       0          0       0
# 98   10.267900  2020-01-22          0       0          0       0
# 99   39.782300  2020-01-22          0       0          0       0
#
#                WHO Region
# 0   Eastern Mediterranean
# 1                  Europe
# 2                  Africa
# 3                  Europe
# 4                  Africa
# 5                Americas
# 6                Americas
# 7                  Europe
# 8         Western Pacific
# 9         Western Pacific
# 10        Western Pacific
# 11        Western Pacific
# 12        Western Pacific
# 13        Western Pacific
# 14        Western Pacific
# 15        Western Pacific
# 16                 Europe
# 17                 Europe
# 18               Americas
# 19  Eastern Mediterranean
# 20        South-East Asia
# 21               Americas
# 22                 Europe
# 23                 Europe
# 24                 Africa
# 25        South-East Asia
# 26               Americas
# 27                 Europe
# 28               Americas
# 29        Western Pacific
# 30                 Europe
# 31                 Africa
# 32                 Africa
# 33        Western Pacific
# 34                 Africa
# 35               Americas
# 36               Americas
# 37               Americas
# 38               Americas
# 39               Americas
# 40               Americas
# 41               Americas
# 42               Americas
# 43               Americas
# 44               Americas
# 45                 Africa
# 46                 Africa
# 47               Americas
# 48        Western Pacific
# 49        Western Pacific
# 50        Western Pacific
# 51        Western Pacific
# 52        Western Pacific
# 53        Western Pacific
# 54        Western Pacific
# 55        Western Pacific
# 56        Western Pacific
# 57        Western Pacific
# 58        Western Pacific
# 59        Western Pacific
# 60        Western Pacific
# 61        Western Pacific
# 62        Western Pacific
# 63        Western Pacific
# 64        Western Pacific
# 65        Western Pacific
# 66        Western Pacific
# 67        Western Pacific
# 68        Western Pacific
# 69        Western Pacific
# 70        Western Pacific
# 71        Western Pacific
# 72        Western Pacific
# 73        Western Pacific
# 74        Western Pacific
# 75        Western Pacific
# 76        Western Pacific
# 77        Western Pacific
# 78        Western Pacific
# 79        Western Pacific
# 80        Western Pacific
# 81               Americas
# 82                 Africa
# 83                 Africa
# 84               Americas
# 85                 Africa
# 86                 Europe
# 87               Americas
# 88                 Europe
# 89                 Europe
# 90                 Europe
# 91                 Europe
# 92                 Europe
# 93  Eastern Mediterranean
# 94               Americas
# 95               Americas
# 96  Eastern Mediterranean
# 97               Americas
# 98                 Africa
# 99                 Africa

# %%
geolocator = Nominatim(user_agent="geoapiExercises")
location=geolocator.reverse([df['Lat'][8],df['Long'][8]])
address=location.raw['address']
state=address.get('territory', '')
state
# Out:
# 'Australian Capital Territory'

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49068 entries, 0 to 49067
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Province/State  14664 non-null  object
#  1   Country/Region  49068 non-null  object
#  2   Lat             49068 non-null  float64
#  3   Long            49068 non-null  float64
#  4   Date            49068 non-null  object
#  5   Confirmed       49068 non-null  int64
#  6   Deaths          49068 non-null  int64
#  7   Recovered       49068 non-null  int64
#  8   Active          49068 non-null  int64
#  9   WHO Region      49068 non-null  object
# dtypes: float64(2), int64(4), object(4)
# memory usage: 3.7+ MB

# %%
df.describe()
# Out:
#                 Lat          Long     Confirmed         Deaths     Recovered  \
# count  49068.000000  49068.000000  4.906800e+04   49068.000000  4.906800e+04
# mean      21.433730     23.528236  1.688490e+04     884.179160  7.915713e+03
# std       24.950320     70.442740  1.273002e+05    6313.584411  5.480092e+04
# min      -51.796300   -135.000000  0.000000e+00       0.000000  0.000000e+00
# 25%        7.873054    -15.310100  4.000000e+00       0.000000  0.000000e+00
# 50%       23.634500     21.745300  1.680000e+02       2.000000  2.900000e+01
# 75%       41.204380     80.771797  1.518250e+03      30.000000  6.660000e+02
# max       71.706900    178.065000  4.290259e+06  148011.000000  1.846641e+06
#
#              Active
# count  4.906800e+04
# mean   8.085012e+03
# std    7.625890e+04
# min   -1.400000e+01
# 25%    0.000000e+00
# 50%    2.600000e+01
# 75%    6.060000e+02
# max    2.816444e+06

# %%
#(Optional step) Data cleaning if required.

# %%
print(df.shape)
df.drop('Province/State',inplace=True,axis=1)
print(df.shape)
# Out:
# (49068, 10)
# (49068, 9)

# %%
#3 which country had highest covid DEATHS in january 2020.

# %%
#4 which WHO region had highest ACTIVE covid cases in March 2020.

# %%
#5 print top 5 countries with highest CONFIRMED covid cases. Print month wise.

# %%
#6 top 3 countries with highest DEATH covid cases print month wise.

# %%
#7 print countries which are amongst top 10 with highest CONFIRMED cases 
# for 3 months consecutively.

# %%
#8 how many total CONFIRMED cases in Asia as per dataset

# %%
#9 Which WHO region have highest DEATHS?

# %%
#10 print top 10 contries with LOWEST CONFIRMED:DEATH ratio print month wise.

# %%
#11 print India's CONFIRMED:RECOVERED cases ratio in the month of March

# %%
#12 which month have highest active cases in USA.

# %% [markdown]
# ## EDA & Visualization
#
# #### You have to follow the below steps. You can show creativity but document every step
#
# Univariate Analysis
#   * Categorical
#       - value count
#       - top unique values
#       - bar plot
#   * Numerical
#       - Distribution plot or line plot
#       - statistical info about column ( 3m, Std dev)
#       - find type of distribution
#
# Bivarite Analysis
#   * Numerical -  Numerical
#       - Pairplot for all the numeric variables
#       - heatmap of correlations
#   * Categorcal - categorical
#       - value_counts comparsion
#   * categorical - numerical
#       - category wise sum,mean
#       - timeline + numerical line plot
#
# Moving averages
#   * create new columns for numerical data with moving averages. plot a line graph against timeline, Moving averages will tell you the upcoming trend. use df.window(size=x) look for documentation on pandas official site page

# %%
# create as many cells as required to do EDA and visulization. show your creativity.

# %% [markdown]
# # Statistics

# %%
#13 write a function to calculate standard deviation. (don't use builtin methods)

# %%
#14 write a function to calculate pearson's r for two numerical columns.

# %%
#15 what is central limit theorem.

# %% [markdown]
# ## Hypothesis testing
#
# Critical Value Method
#
# Consider this problem — H₀: μ ≤ 350 and H₁: μ > 350
#
# In case of a two-tailed test, you find the z-score of 0.975 in the z-table, since 0.975 was cumulative probability of UCV in that case. In this problem, what would be the cumulative probability of critical point in this example for the same significance level of 5%? Type your answer below cell

# %%
#16 Type your answer here.

# %% [markdown]
# Using Critical Value Method
#
# Consider this problem, H₀: μ ≤ 350 and H₁: μ > 350
#
# So, the Zc comes out to be 1.645. Now, find the critical value for the given Zc and make the decision to accept or reject the null hypothesis.
#
# μ = 350     σ = 90       N (Sample size) = 36    ¯x= 370.16

# %%
#17 type your answer here.

# %% [markdown]
# Let’s solve the following problem on how to make a decision about any hypothesis using the p-value method.
#
#  You are working as a data analyst at an auditing firm. A manufacturer claims that the average life of its product is 36 months. An auditor selects a sample of 49 units of the product, and calculates the average life to be 34.5 months. The population standard deviation is 4 months. Test the manufacturer’s claim at 3% significance level using the p-value method.
#
#  First, formulate the hypotheses for this two-tailed test, which would be:
#
#                        H₀: μ = 36 months and H₁: μ ≠ 36 months
#
#  Now, you need to follow the three steps to find the p-value and make a decision.
#
#
# STEP 1 - Calculate the value of z-score for the sample mean point on the distribution. Calculate z-score for sample mean (¯x) = 34.5 months.
#
#
# STEP 2 - Calculate the p-value from the cumulative probability for the calculated z-score using the z-table.(Hint z-score of -2.62 )
#
#
#
# Hint: The sample mean is on the left side of the distribution and it is a two-tailed test.

# %%
#18 type your answer
