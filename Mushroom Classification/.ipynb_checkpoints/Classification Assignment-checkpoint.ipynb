# %% [markdown]
# #### https://www.kaggle.com/datasets/uciml/mushroom-classification
#
# Download dataset from above link, you will predict if mushroom is edible or not

# %% [markdown]
# # Classification Assignment (End-to-End)

# %%
#import libraries
import pandas as pd, numpy as np, matplotlib.pyplot as plt, seaborn as sns, warnings
from sklearn.preprocessing import LabelEncoder
warnings.filterwarnings('ignore')
pd.options.display.max_columns=100

# %%
#Data understanding
df=pd.read_csv(r"A:\datasets\mushrooms.csv")
df.shape
# Out:
# (8124, 23)

# %%
df.describe()
# Out:
#        class cap-shape cap-surface cap-color bruises  odor gill-attachment  \
# count   8124      8124        8124      8124    8124  8124            8124
# unique     2         6           4        10       2     9               2
# top        e         x           y         n       f     n               f
# freq    4208      3656        3244      2284    4748  3528            7914
#
#        gill-spacing gill-size gill-color stalk-shape stalk-root  \
# count          8124      8124       8124        8124       8124
# unique            2         2         12           2          5
# top               c         b          b           t          b
# freq           6812      5612       1728        4608       3776
#
#        stalk-surface-above-ring stalk-surface-below-ring  \
# count                      8124                     8124
# unique                        4                        4
# top                           s                        s
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8124 entries, 0 to 8123
# Data columns (total 23 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   class                     8124 non-null   object
#  1   cap-shape                 8124 non-null   object
#  2   cap-surface               8124 non-null   object
#  3   cap-color                 8124 non-null   object
#  4   bruises                   8124 non-null   object
#  5   odor                      8124 non-null   object
#  6   gill-attachment           8124 non-null   object
#  7   gill-spacing              8124 non-null   object
#  8   gill-size                 8124 non-null   object
#  9   gill-color                8124 non-null   object
#  10  stalk-shape               8124 non-null   object
#  11  stalk-root                8124 non-null   object
#  12  stalk-surface-above-ring  8124 non-null   object
# ...

# %%
df.head(10)
# Out:
#   class cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 0     p         x           s         n       t    p               f
# 1     e         x           s         y       t    a               f
# 2     e         b           s         w       t    l               f
# 3     p         x           y         w       t    p               f
# 4     e         x           s         g       f    n               f
# 5     e         x           y         y       t    a               f
# 6     e         b           s         w       t    a               f
# 7     e         b           y         w       t    l               f
# 8     p         x           y         w       t    p               f
# 9     e         b           s         y       t    a               f
#
#   gill-spacing gill-size gill-color stalk-shape stalk-root  \
# 0            c         n          k           e          e
# 1            c         b          k           e          c
# ...

# %% [markdown]
# ## Data Cleaning

# %% [markdown]
# ### Checking columns with null values

# %%
for i in df.columns:
    print(i,':',(df[i].isnull().sum()/df.shape[0])*100,'%')
# Out:
# class : 0.0 %
# cap-shape : 0.0 %
# cap-surface : 0.0 %
# cap-color : 0.0 %
# bruises : 0.0 %
# odor : 0.0 %
# gill-attachment : 0.0 %
# gill-spacing : 0.0 %
# gill-size : 0.0 %
# gill-color : 0.0 %
# stalk-shape : 0.0 %
# stalk-root : 0.0 %
# stalk-surface-above-ring : 0.0 %
# stalk-surface-below-ring : 0.0 %
# stalk-color-above-ring : 0.0 %
# stalk-color-below-ring : 0.0 %
# veil-type : 0.0 %
# veil-color : 0.0 %
# ring-number : 0.0 %
# ring-type : 0.0 %
# spore-print-color : 0.0 %
# population : 0.0 %
# habitat : 0.0 %

# %%
for i in df.columns:
    print(i)
    print(df[i].value_counts())
    print()
# Out:
# class
# e    4208
# p    3916
# Name: class, dtype: int64
#
# cap-shape
# x    3656
# f    3152
# k     828
# b     452
# s      32
# c       4
# Name: cap-shape, dtype: int64
#
# cap-surface
# y    3244
# s    2556
# f    2320
# g       4
# Name: cap-surface, dtype: int64
#
# cap-color
# n    2284
# g    1840
# e    1500
# y    1072
# w    1040
# b     168
# p     144
# c      44
# r      16
# u      16
# Name: cap-color, dtype: int64
#
# bruises
# f    4748
# t    3376
# Name: bruises, dtype: int64
#
# odor
# n    3528
# f    2160
# y     576
# s     576
# l     400
# a     400
# p     256
# c     192
# m      36
# Name: odor, dtype: int64
#
# gill-attachment
# f    7914
# a     210
# Name: gill-attachment, dtype: int64
#
# gill-spacing
# c    6812
# w    1312
# Name: gill-spacing, dtype: int64
#
# gill-size
# b    5612
# n    2512
# Name: gill-size, dtype: int64
#
# gill-color
# b    1728
# p    1492
# w    1202
# n    1048
# g     752
# h     732
# u     492
# k     408
# ...

# %%
lst=['k','b','s','c']
df['cap-shape']=pd.DataFrame(np.where(df['cap-shape'].isin(lst),'others',df['cap-shape']))

# %%
lst=['b','p','c','u','r']
df['cap-color']=pd.DataFrame(np.where(df['cap-color'].isin(lst),'others',df['cap-color']))

# %%
lst=['l','a','p','c','m']
df['odor']=pd.DataFrame(np.where(df['odor'].isin(lst),'others',df['odor']))

# %%
lst=['b','o','e','c','y']
df['stalk-color-above-ring']=pd.DataFrame(np.where(df['stalk-color-above-ring'].isin(lst),'others',df['stalk-color-above-ring']))

# %%
lst=['b','o','e','c','y']
df['stalk-color-below-ring']=pd.DataFrame(np.where(df['stalk-color-below-ring'].isin(lst),'others',df['stalk-color-below-ring']))

# %%
lst=['f','n']
df['ring-type']=pd.DataFrame(np.where(df['ring-type'].isin(lst),'others',df['ring-type']))

# %%
lst=['n','a','c']
df['population']=pd.DataFrame(np.where(df['population'].isin(lst),'others',df['population']))

# %%
#Column Name= spore-print-color
lst=['r','u','o','b','y']
df['spore-print-color']=pd.DataFrame(np.where(df['spore-print-color'].isin(lst),'others',df['spore-print-color']))

# %%
print(df.shape)
df.drop(['veil-type','ring-number','veil-color','gill-attachment','ring-number'],axis=1,inplace=True)
print(df.shape)
# Out:
# (8124, 23)
# (8124, 19)

# %% [markdown]
# #### Inference: Dropped columns which are biased over 92%

# %%
df.corr()
# Out:
#                              class  cap-shape  cap-surface  cap-color  \
# class                     1.000000  -0.024529     0.178446  -0.013613
# cap-shape                -0.024529   1.000000    -0.010208   0.057859
# cap-surface               0.178446  -0.010208     1.000000  -0.001617
# cap-color                -0.013613   0.057859    -0.001617   1.000000
# bruises                  -0.501530   0.002340     0.070228   0.045173
# odor                      0.051728   0.038486     0.218053  -0.120258
# gill-spacing             -0.348387   0.039044    -0.282306   0.128555
# gill-size                 0.540024   0.009378     0.208100  -0.200436
# gill-color               -0.530566   0.013340    -0.161017   0.129162
# stalk-shape              -0.102019  -0.077762    -0.014123  -0.490737
# stalk-root               -0.379361   0.013040    -0.126245   0.315022
# stalk-surface-above-ring -0.334593   0.035602     0.089090  -0.075847
# ...

# %% [markdown]
# # EDA

# %% [markdown]
# ### Univarite Analysis

# %%
df.columns
# Out:
# Index(['class', 'cap-shape', 'cap-surface', 'cap-color', 'bruises', 'odor',
#        'gill-spacing', 'gill-size', 'gill-color', 'stalk-shape', 'stalk-root',
#        'stalk-surface-above-ring', 'stalk-surface-below-ring',
#        'stalk-color-above-ring', 'stalk-color-below-ring', 'ring-type',
#        'spore-print-color', 'population', 'habitat'],
#       dtype='object')

# %%
plt.pie(df['class'].value_counts(),autopct="%0.02f",labels=['edible','poisonous'])
plt.title('Edible VS Poisonous Mushrooms')
plt.show()

# %%
df['cap-shape'].value_counts().plot(kind='bar')
plt.xlabel('cap shape')
plt.ylabel('count')
plt.show()

# %%
df['cap-surface'].value_counts().plot(kind='bar')
plt.xlabel('cap-surface')
plt.ylabel('count')
plt.show()

# %%
df['cap-color'].value_counts().plot(kind='bar')
plt.xlabel('cap-colour')
plt.ylabel('count')
plt.show()

# %%
plt.pie(df['bruises'].value_counts(),autopct='%0.02f',labels=['false','True'])
plt.title('Bruises')
plt.show()

# %%
df['odor'].value_counts().plot(kind='bar')
plt.xlabel('odor-type')
plt.ylabel('count')
plt.show()

# %%
for i in df.columns:
    if len(df[i].value_counts()) >3:
        df[i].value_counts().plot(kind='bar')
        plt.xlabel(i)
        plt.ylabel('count')
        plt.show()
    else:
        plt.pie(df[i].value_counts(),autopct="%0.02f")
        plt.title(i)
        plt.show()

# %%
#bivarite

# %%
x=df['class'].unique().tolist()
y=df['stalk-shape'].value_counts().tolist()
z=df['bruises'].value_counts().tolist()
plt.bar(x,y,color='red',alpha=0.7)
plt.bar(x,z,alpha=0.7)
plt.xticks(np.arange(len(x)),x)
plt.show()

# %%
#visulization (if any extra)

# %%
plt.figure(figsize=(20,20))
sns.heatmap(df.corr(),annot=True)
plt.show()

# %% [markdown]
# ### Encoding

# %%
for i in df.columns:
    print(i)
    print(df[i].value_counts())
    print()
# Out:
# class
# e    4208
# p    3916
# Name: class, dtype: int64
#
# cap-shape
# x         3656
# f         3152
# others    1316
# Name: cap-shape, dtype: int64
#
# cap-surface
# y    3244
# s    2556
# f    2320
# g       4
# Name: cap-surface, dtype: int64
#
# cap-color
# n         2284
# g         1840
# e         1500
# y         1072
# w         1040
# others     388
# Name: cap-color, dtype: int64
#
# bruises
# f    4748
# t    3376
# Name: bruises, dtype: int64
#
# odor
# n         3528
# f         2160
# others    1284
# y          576
# s          576
# Name: odor, dtype: int64
#
# gill-spacing
# c    6812
# w    1312
# Name: gill-spacing, dtype: int64
#
# gill-size
# b    5612
# n    2512
# Name: gill-size, dtype: int64
#
# gill-color
# b    1728
# p    1492
# w    1202
# n    1048
# g     752
# h     732
# u     492
# k     408
# e      96
# y      86
# o      64
# r      24
# Name: gill-color, dtype: int64
#
# stalk-shape
# t    4608
# e    3516
# ...

# %%
for i in df.columns:
    label_encoding=LabelEncoder()
    df[i]=label_encoding.fit_transform(df[i])

# %%
for i in df.columns:
    print(i)
    print(df[i].value_counts())
    print()
# Out:
# class
# 0    4208
# 1    3916
# Name: class, dtype: int64
#
# cap-shape
# 2    3656
# 0    3152
# 1    1316
# Name: cap-shape, dtype: int64
#
# cap-surface
# 3    3244
# 2    2556
# 0    2320
# 1       4
# Name: cap-surface, dtype: int64
#
# cap-color
# 2    2284
# 1    1840
# 0    1500
# 5    1072
# 4    1040
# 3     388
# Name: cap-color, dtype: int64
#
# bruises
# 0    4748
# 1    3376
# Name: bruises, dtype: int64
#
# odor
# 1    3528
# 0    2160
# 2    1284
# 3     576
# 4     576
# Name: odor, dtype: int64
#
# gill-spacing
# 0    6812
# 1    1312
# Name: gill-spacing, dtype: int64
#
# gill-size
# 0    5612
# 1    2512
# Name: gill-size, dtype: int64
#
# gill-color
# 0     1728
# 7     1492
# 10    1202
# 5     1048
# 2      752
# 3      732
# 9      492
# 4      408
# 1       96
# 11      86
# 6       64
# 8       24
# Name: gill-color, dtype: int64
#
# stalk-shape
# 1    4608
# 0    3516
# Name: stalk-shape, dtype: int64
#
# stalk-root
# 1    3776
# 0    2480
# 3    1120
# ...

# %% [markdown]
# ## Feature Selection

# %% [markdown]
# ### Dropping using Variance Threshold

# %%
x=df.drop('class',axis=1)
y=df['class']

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.3,random_state=0)
x_train.shape,x_test.shape,y_train.shape,y_test.shape
# Out:
# ((5686, 18), (2438, 18), (5686,), (2438,))

# %%
x_train.corr()
# Out:
#                           cap-shape  cap-surface  cap-color   bruises  \
# cap-shape                  1.000000    -0.018979   0.053656 -0.004750
# cap-surface               -0.018979     1.000000   0.008883  0.071568
# cap-color                  0.053656     0.008883   1.000000  0.050458
# bruises                   -0.004750     0.071568   0.050458  1.000000
# odor                       0.034764     0.222634  -0.114785 -0.016097
# gill-spacing               0.034573    -0.279803   0.125759 -0.305329
# gill-size                  0.005076     0.214386  -0.192327 -0.366533
# gill-color                 0.016451    -0.164088   0.135550  0.528166
# stalk-shape               -0.078280    -0.018445  -0.481733  0.090112
# stalk-root                 0.010256    -0.128702   0.322676  0.237922
# stalk-surface-above-ring   0.030921     0.091384  -0.071465  0.463384
# stalk-surface-below-ring   0.020405     0.111228  -0.032984  0.457986
# ...

# %%
plt.figure(figsize=(20,15))
sns.heatmap(x_train.corr() , annot=True , cmap=plt.cm.CMRmap_r)
plt.show()

# %%
def correlation(dataset,threshold):
    corr_cols=set()
    corr_matrix=dataset.corr()
    for i in range(len(corr_matrix.columns)):
        for j in range(i):
            if (corr_matrix.iloc[i,j]) > threshold:
                colname=corr_matrix.columns[i]
                corr_cols.add(colname)
    return corr_cols

# %%
corr_features=correlation(x_train,0.7)
len(corr_features)
# Out:
# 1

# %%
corr_features
# Out:
# {'ring-type'}

# %%
x_train.drop(corr_features,axis=1)
x_test.drop(corr_features,axis=1)
x_train
# Out:
#       cap-shape  cap-surface  cap-color  bruises  odor  gill-spacing  \
# 5314          2            2          4        1     0             0
# 2075          2            2          5        1     2             0
# 5165          0            2          4        1     0             0
# 1155          1            3          4        1     2             0
# 4448          2            3          5        0     0             0
# ...         ...          ...        ...      ...   ...           ...
# 4931          2            3          0        1     1             0
# 3264          2            0          1        0     0             0
# 1653          2            2          1        0     1             1
# 2607          0            0          2        1     1             0
# 2732          2            3          1        1     1             0
#
#       gill-size  gill-color  stalk-shape  stalk-root  \
# 5314          0           3            1           1
# ...

# %% [markdown]
# ### Inference: Using pearson correlation deleted 'ring-type' column

# %%
print(df.shape)
df.drop('ring-type',axis=1,inplace=True)
print(df.shape)
# Out:
# (8124, 19)
# (8124, 18)

# %% [markdown]
# ## 3. Dropping using Information gain - Mutual Information Gain - Classification
#
#
# Mutual Information
# MI Estimate mutual information for a discrete target variable.
#
# Mutual information (MI) between two random variables is a non-negative value, which measures the dependency between the variables. It is equal to zero if and only if two random variables are independent, and higher values mean higher dependency.
#
# The function relies on nonparametric methods based on entropy estimation from k-nearest neighbors distances.
#
# Inshort
#
# A quantity called mutual information measures the amount of information one can obtain from one random variable given another.
#
# The mutual information between two random variables X and Y can be stated formally as follows:
#
#  I(X;Y) = H(X) - H(X|Y) Where I(X;Y) is the mutual information for X and Y, H(X) is the entropy for X and H(X|Y) is the conditional entropy for X given Y. The result has the units of bits.

# %%
df.head()
# Out:
#    class  cap-shape  cap-surface  cap-color  bruises  odor  gill-spacing  \
# 0      1          2            2          2        1     2             0
# 1      0          2            2          5        1     2             0
# 2      0          1            2          4        1     2             0
# 3      1          2            3          4        1     2             0
# 4      0          2            2          1        0     1             1
#
#    gill-size  gill-color  stalk-shape  stalk-root  stalk-surface-above-ring  \
# 0          1           4            0           3                         2
# 1          0           4            0           2                         2
# 2          0           5            0           2                         2
# 3          1           5            0           3                         2
# 4          0           4            1           3                         2
#
# ...

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(df.drop('class',axis=1),df['class'],test_size=0.3,random_state=0)
x_train.shape,x_test.shape,y_train.shape,y_test.shape
# Out:
# ((5686, 17), (2438, 17), (5686,), (2438,))

# %%
x_train.head()
# Out:
#       cap-shape  cap-surface  cap-color  bruises  odor  gill-spacing  \
# 5314          2            2          4        1     0             0
# 2075          2            2          5        1     2             0
# 5165          0            2          4        1     0             0
# 1155          1            3          4        1     2             0
# 4448          2            3          5        0     0             0
#
#       gill-size  gill-color  stalk-shape  stalk-root  \
# 5314          0           3            1           1
# 2075          0           4            0           2
# 5165          0           7            1           1
# 1155          0           4            0           2
# 4448          0           3            0           1
#
#       stalk-surface-above-ring  stalk-surface-below-ring  \
# 5314                         0                         2
# 2075                         2                         2
# ...

# %%
#applying the above IG formula with the help of inbuilt lib to find the Information gain
from sklearn.feature_selection import mutual_info_classif
mutual_info = mutual_info_classif(x_train, y_train)
mutual_info
# Out:
# array([0.        , 0.01235079, 0.0152875 , 0.14144151, 0.52148989,
#        0.08558481, 0.16138926, 0.28372399, 0.00197875, 0.09809827,
#        0.18771155, 0.1858255 , 0.10440857, 0.09903193, 0.30509546,
#        0.12814217, 0.10833993])

# %%
mutual_info = pd.Series(mutual_info)
mutual_info.index = x_train.columns
mutual_info.sort_values(ascending=False)
# Out:
# odor                        0.521490
# spore-print-color           0.305095
# gill-color                  0.283724
# stalk-surface-above-ring    0.187712
# stalk-surface-below-ring    0.185826
# gill-size                   0.161389
# bruises                     0.141442
# population                  0.128142
# habitat                     0.108340
# stalk-color-above-ring      0.104409
# stalk-color-below-ring      0.099032
# stalk-root                  0.098098
# gill-spacing                0.085585
# cap-color                   0.015287
# cap-surface                 0.012351
# stalk-shape                 0.001979
# cap-shape                   0.000000
# dtype: float64

# %%
mutual_info.sort_values(ascending=False).plot.bar(figsize=(20,8))
plt.title('Plotting the information gain of all the columns')
plt.show()

# %%
from sklearn.feature_selection import SelectKBest

#Selecting the top 14 important features
imp_cols=SelectKBest(mutual_info_classif,k=9)
imp_cols.fit(x_train,y_train)
final_cols = x_train.columns[imp_cols.get_support()].tolist()

# %%
x_train=x_train[final_cols]
x_train
# Out:
#       bruises  odor  gill-size  gill-color  stalk-surface-above-ring  \
# 5314        1     0          0           3                         0
# 2075        1     2          0           4                         2
# 5165        1     0          0           7                         0
# 1155        1     2          0           4                         2
# 4448        0     0          0           3                         1
# ...       ...   ...        ...         ...                       ...
# 4931        1     1          0           1                         2
# 3264        0     0          0           3                         1
# 1653        0     1          0           3                         0
# 2607        1     1          0           5                         2
# 2732        1     1          0          10                         2
#
#       stalk-surface-below-ring  spore-print-color  population  habitat
# ...

# %%
x_test=x_test[final_cols]

# %%
x_test
# Out:
#       bruises  odor  gill-size  gill-color  stalk-surface-above-ring  \
# 380         1     2          1           7                         2
# 3641        1     1          0           7                         2
# 273         1     2          0           4                         2
# 1029        0     1          0           4                         2
# 684         1     1          0           7                         2
# ...       ...   ...        ...         ...                       ...
# 520         1     2          0          10                         2
# 36          0     1          1           4                         2
# 7959        0     0          1           0                         1
# 6520        0     4          1           0                         2
# 6005        0     3          1           0                         2
#
#       stalk-surface-below-ring  spore-print-color  population  habitat
# ...

# %% [markdown]
# # Model building

# %% [markdown]
# ### Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression

lr=LogisticRegression()
lr.fit(x_train,y_train)
prediction = lr.predict(x_test)
print('Confusion Matrix:')
print(confusion_matrix(prediction,y_test))
print()
print('Classification Report:')
print(classification_report(prediction,y_test))
print()
print('Accuracy Score:')
print(accuracy_score(prediction,y_test))
print()
print('F1 score:')
print(f1_score(prediction,y_test))
# Out:
# Confusion Matrix:
# [[1172   80]
#  [ 100 1086]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.92      0.94      0.93      1252
#            1       0.93      0.92      0.92      1186
#
#     accuracy                           0.93      2438
#    macro avg       0.93      0.93      0.93      2438
# weighted avg       0.93      0.93      0.93      2438
#
#
# Accuracy Score:
# 0.92616899097621
#
# F1 score:
# 0.9234693877551021

# %% [markdown]
# ### Navie bayes classifier

# %%
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import confusion_matrix, f1_score, accuracy_score, classification_report

gnb = GaussianNB()
gnb.fit(x_train, y_train)
prediction = gnb.predict(x_test)
print('Confusion Matrix:')
print(confusion_matrix(prediction,y_test))
print()
print('Classification Report:')
print(classification_report(prediction,y_test))
print()
print('Accuracy Score:')
print(accuracy_score(prediction,y_test))
print()
print('F1 score')
print(f1_score(prediction,y_test))
# Out:
# Confusion Matrix:
# [[1181   77]
#  [  91 1089]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.93      0.94      0.93      1258
#            1       0.93      0.92      0.93      1180
#
#     accuracy                           0.93      2438
#    macro avg       0.93      0.93      0.93      2438
# weighted avg       0.93      0.93      0.93      2438
#
#
# Accuracy Score:
# 0.9310910582444627
#
# F1 score
# 0.928388746803069

# %% [markdown]
# ### SVC classifier

# %%
from sklearn.svm import SVC

svc = SVC()
svc.fit(x_train,y_train)
prediction = svc.predict(x_test)

from sklearn.metrics import classification_report, accuracy_score, confusion_matrix, f1_score

print('Accuracy Score:')
print(accuracy_score(prediction,y_test))
print()
print('F1 score')
print(f1_score(prediction,y_test))
print()
print('classification report')
print(classification_report(prediction,y_test))
print()
print('Confusion Matrix:')
print(confusion_matrix(prediction,y_test))
# Out:
# Accuracy Score:
# 0.9811320754716981
#
# F1 score
# 0.9803082191780822
#
# classification report
#               precision    recall  f1-score   support
#
#            0       0.98      0.98      0.98      1268
#            1       0.98      0.98      0.98      1170
#
#     accuracy                           0.98      2438
#    macro avg       0.98      0.98      0.98      2438
# weighted avg       0.98      0.98      0.98      2438
#
#
# Confusion Matrix:
# [[1247   21]
#  [  25 1145]]

# %% [markdown]
# ### Decision Tree Classifier

# %%
# %%time
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import

# %% [markdown]
# ### Random forest classifier

# %% [markdown]
# # Metrics

# %%
# create a data frame showing metrics of the above models
#explain which model does it better

# %% [markdown]
# # GridSearch CV

# %%
# implement grid search for the best model, recommend best hyperparameters
